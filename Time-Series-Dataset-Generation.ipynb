# %% [markdown]
# # ***Libraries***

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import random
import json

# %% [markdown]
# # ***Time-Series Data Generation***

# %%
def count_files_and_organize_by_subfolder(folder_path):
    subfolder_files = {}

    for subdir, _, files in os.walk(folder_path):
        subfolder_name = os.path.basename(subdir)
        if subfolder_name not in subfolder_files:
            subfolder_files[subfolder_name] = []

        subfolder_files[subfolder_name].extend(files)

    return subfolder_files

def print_subfolder_files_info(subfolder_files):
    for subfolder, files in subfolder_files.items():
        print(f"Subfolder: {subfolder}")
        #for file in files:
            #print(f"  File: {file}")
        print(f"Number of files in '{subfolder}': {len(files)}\n")

# %%
tsb_uad_pub_folder_path = '../TSB-UAD-Public/TSB-UAD-Public'
subfolder_files = count_files_and_organize_by_subfolder(tsb_uad_pub_folder_path)
del subfolder_files['TSB-UAD-Public']
print_subfolder_files_info(subfolder_files)
# Out:
# Subfolder: NASA-MSL
# Number of files in 'NASA-MSL': 54
#
# Subfolder: KDD21
# Number of files in 'KDD21': 250
#
# Subfolder: MITDB
# Number of files in 'MITDB': 32
#
# Subfolder: SVDB
# Number of files in 'SVDB': 115
#
# Subfolder: NASA-SMAP
# Number of files in 'NASA-SMAP': 108
#
# Subfolder: MGAB
# Number of files in 'MGAB': 10
#
# Subfolder: Genesis
# Number of files in 'Genesis': 6
#
# Subfolder: YAHOO
# Number of files in 'YAHOO': 367
#
# Subfolder: OPPORTUNITY
# Number of files in 'OPPORTUNITY': 465
#
# Subfolder: GHL
# Number of files in 'GHL': 126
#
# Subfolder: ECG
# Number of files in 'ECG': 53
#
# Subfolder: SMD
# Number of files in 'SMD': 281
#
# Subfolder: IOPS
# Number of files in 'IOPS': 58
#
# Subfolder: Occupancy
# Number of files in 'Occupancy': 10
#
# Subfolder: NAB
# Number of files in 'NAB': 58
#
# Subfolder: Dodgers
# Number of files in 'Dodgers': 1
#
# Subfolder: Daphnet
# Number of files in 'Daphnet': 45
#
# Subfolder: SensorScope
# Number of files in 'SensorScope': 23

# %%
def create_normality_dicts(subfolder_files):
    # Create Normality_1
    normality_1 = {}
    for subfolder, files in subfolder_files.items():
        if files:
            num_files_to_take = min(random.randint(1, 3), len(files))
            normality_1[subfolder] = random.sample(files, num_files_to_take)
    
    # Create Normality_2
    normality_2 = {}
    subfolder_list = list(normality_1.keys())
    for i in range(len(subfolder_list)):
        for j in range(i + 1, len(subfolder_list)):
            subfolder_a = subfolder_list[i]
            subfolder_b = subfolder_list[j]
            files_a = normality_1[subfolder_a]
            files_b = normality_1[subfolder_b]
            if files_a and files_b:
                file_a = random.choice(files_a)
                file_b = random.choice(files_b)
                key = f"{file_a}+{file_b}"
                normality_2[key] = (subfolder_a, subfolder_b)
    
    # Create Normality_3
    normality_3 = {}
    for i in range(len(subfolder_list)):
        for j in range(i + 1, len(subfolder_list)):
            for k in range(j + 1, len(subfolder_list)):
                subfolder_a = subfolder_list[i]
                subfolder_b = subfolder_list[j]
                subfolder_c = subfolder_list[k]
                files_a = normality_1[subfolder_a]
                files_b = normality_1[subfolder_b]
                files_c = normality_1[subfolder_c]
                if files_a and files_b and files_c:
                    file_a = random.choice(files_a)
                    file_b = random.choice(files_b)
                    file_c = random.choice(files_c)
                    key = f"{file_a}+{file_b}+{file_c}"
                    normality_3[key] = (subfolder_a, subfolder_b, subfolder_c)

    return normality_1, normality_2, normality_3

# %%
normality_1, normality_2, normality_3 = create_normality_dicts(subfolder_files)

# %%
print("Normality_1:")
for key, value in normality_1.items():
    print(f"{key}: {value}")

print("\nNormality_2:")
for key, value in normality_2.items():
    print(f"{key}: {value}")

print("\nNormality_3:")
for key, value in normality_3.items():
    print(f"{key}: {value}")
# Out:
# Normality_1:
# NASA-MSL: ['F-8.test.out']
# KDD21: ['242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out', '166_UCR_Anomaly_apneaecg_10000_12240_12308.out', '083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out']
# MITDB: ['223.test.csv@2.out', '234.test.csv@1.out']
# SVDB: ['893.test.csv@2.out']
# NASA-SMAP: ['D-5.train.out', 'A-9.test.out', 'A-4.train.out']
# MGAB: ['2.test.out', '4.test.out']
# Genesis: ['genesis-anomalies.test.csv@6.out']
# YAHOO: ['Yahoo_A2synthetic_72_data.out']
# OPPORTUNITY: ['S4-ADL3.test.csv@124.out', 'S4-ADL4.test.csv@120.out']
# GHL: ['05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out']
# ECG: ['MBA_ECG14046_data_38.out', 'MBA_ECG801_data.out']
# SMD: ['machine-3-7.test.csv@7.out', 'machine-3-6.test.csv@9.out', 'machine-2-8.test.csv@7.out']
# IOPS: ['KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out', 'KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out', 'KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out']
# Occupancy: ['room-occupancy-0.test.csv@3.out']
# NAB: ['NAB_data_KnownCause_6.out', 'NAB_data_CloudWatch_12.out']
# Dodgers: ['101-freeway-traffic.test.out']
# Daphnet: ['S03R03E4.test.csv@2.out', 'S09R01E4.test.csv@3.out', 'S01R02E0.test.csv@1.out']
# SensorScope: ['stb-19.test.out']
#
# Normality_2:
# F-8.test.out+166_UCR_Anomaly_apneaecg_10000_12240_12308.out: ('NASA-MSL', 'KDD21')
# F-8.test.out+234.test.csv@1.out: ('NASA-MSL', 'MITDB')
# F-8.test.out+893.test.csv@2.out: ('NASA-MSL', 'SVDB')
# F-8.test.out+A-9.test.out: ('NASA-MSL', 'NASA-SMAP')
# F-8.test.out+2.test.out: ('NASA-MSL', 'MGAB')
# F-8.test.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'Genesis')
# F-8.test.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'YAHOO')
# F-8.test.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'OPPORTUNITY')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'GHL')
# F-8.test.out+MBA_ECG801_data.out: ('NASA-MSL', 'ECG')
# F-8.test.out+machine-2-8.test.csv@7.out: ('NASA-MSL', 'SMD')
# F-8.test.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('NASA-MSL', 'IOPS')
# F-8.test.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'Occupancy')
# F-8.test.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'NAB')
# F-8.test.out+101-freeway-traffic.test.out: ('NASA-MSL', 'Dodgers')
# F-8.test.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'Daphnet')
# F-8.test.out+stb-19.test.out: ('NASA-MSL', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+234.test.csv@1.out: ('KDD21', 'MITDB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out: ('KDD21', 'SVDB')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+A-4.train.out: ('KDD21', 'NASA-SMAP')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+4.test.out: ('KDD21', 'MGAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'Genesis')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'YAHOO')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S4-ADL4.test.csv@120.out: ('KDD21', 'OPPORTUNITY')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'GHL')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+MBA_ECG801_data.out: ('KDD21', 'ECG')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+machine-3-7.test.csv@7.out: ('KDD21', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('KDD21', 'IOPS')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'Occupancy')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+NAB_data_KnownCause_6.out: ('KDD21', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+101-freeway-traffic.test.out: ('KDD21', 'Dodgers')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S03R03E4.test.csv@2.out: ('KDD21', 'Daphnet')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+stb-19.test.out: ('KDD21', 'SensorScope')
# 223.test.csv@2.out+893.test.csv@2.out: ('MITDB', 'SVDB')
# 234.test.csv@1.out+A-9.test.out: ('MITDB', 'NASA-SMAP')
# 234.test.csv@1.out+2.test.out: ('MITDB', 'MGAB')
# 234.test.csv@1.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'Genesis')
# 223.test.csv@2.out+Yahoo_A2synthetic_72_data.out: ('MITDB', 'YAHOO')
# 223.test.csv@2.out+S4-ADL4.test.csv@120.out: ('MITDB', 'OPPORTUNITY')
# 234.test.csv@1.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MITDB', 'GHL')
# 234.test.csv@1.out+MBA_ECG801_data.out: ('MITDB', 'ECG')
# 234.test.csv@1.out+machine-3-7.test.csv@7.out: ('MITDB', 'SMD')
# 234.test.csv@1.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('MITDB', 'IOPS')
# 234.test.csv@1.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'Occupancy')
# 234.test.csv@1.out+NAB_data_KnownCause_6.out: ('MITDB', 'NAB')
# 234.test.csv@1.out+101-freeway-traffic.test.out: ('MITDB', 'Dodgers')
# 234.test.csv@1.out+S01R02E0.test.csv@1.out: ('MITDB', 'Daphnet')
# 223.test.csv@2.out+stb-19.test.out: ('MITDB', 'SensorScope')
# 893.test.csv@2.out+A-4.train.out: ('SVDB', 'NASA-SMAP')
# 893.test.csv@2.out+4.test.out: ('SVDB', 'MGAB')
# 893.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('SVDB', 'Genesis')
# 893.test.csv@2.out+Yahoo_A2synthetic_72_data.out: ('SVDB', 'YAHOO')
# 893.test.csv@2.out+S4-ADL3.test.csv@124.out: ('SVDB', 'OPPORTUNITY')
# 893.test.csv@2.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('SVDB', 'GHL')
# 893.test.csv@2.out+MBA_ECG801_data.out: ('SVDB', 'ECG')
# 893.test.csv@2.out+machine-3-7.test.csv@7.out: ('SVDB', 'SMD')
# 893.test.csv@2.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('SVDB', 'IOPS')
# 893.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('SVDB', 'Occupancy')
# 893.test.csv@2.out+NAB_data_CloudWatch_12.out: ('SVDB', 'NAB')
# 893.test.csv@2.out+101-freeway-traffic.test.out: ('SVDB', 'Dodgers')
# 893.test.csv@2.out+S03R03E4.test.csv@2.out: ('SVDB', 'Daphnet')
# 893.test.csv@2.out+stb-19.test.out: ('SVDB', 'SensorScope')
# D-5.train.out+4.test.out: ('NASA-SMAP', 'MGAB')
# A-9.test.out+genesis-anomalies.test.csv@6.out: ('NASA-SMAP', 'Genesis')
# A-9.test.out+Yahoo_A2synthetic_72_data.out: ('NASA-SMAP', 'YAHOO')
# A-4.train.out+S4-ADL4.test.csv@120.out: ('NASA-SMAP', 'OPPORTUNITY')
# D-5.train.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-SMAP', 'GHL')
# A-9.test.out+MBA_ECG14046_data_38.out: ('NASA-SMAP', 'ECG')
# A-9.test.out+machine-3-7.test.csv@7.out: ('NASA-SMAP', 'SMD')
# A-9.test.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-SMAP', 'IOPS')
# D-5.train.out+room-occupancy-0.test.csv@3.out: ('NASA-SMAP', 'Occupancy')
# A-9.test.out+NAB_data_CloudWatch_12.out: ('NASA-SMAP', 'NAB')
# D-5.train.out+101-freeway-traffic.test.out: ('NASA-SMAP', 'Dodgers')
# D-5.train.out+S03R03E4.test.csv@2.out: ('NASA-SMAP', 'Daphnet')
# A-4.train.out+stb-19.test.out: ('NASA-SMAP', 'SensorScope')
# 2.test.out+genesis-anomalies.test.csv@6.out: ('MGAB', 'Genesis')
# 2.test.out+Yahoo_A2synthetic_72_data.out: ('MGAB', 'YAHOO')
# 4.test.out+S4-ADL3.test.csv@124.out: ('MGAB', 'OPPORTUNITY')
# 4.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MGAB', 'GHL')
# 2.test.out+MBA_ECG801_data.out: ('MGAB', 'ECG')
# 2.test.out+machine-3-7.test.csv@7.out: ('MGAB', 'SMD')
# 2.test.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('MGAB', 'IOPS')
# 2.test.out+room-occupancy-0.test.csv@3.out: ('MGAB', 'Occupancy')
# 2.test.out+NAB_data_CloudWatch_12.out: ('MGAB', 'NAB')
# 2.test.out+101-freeway-traffic.test.out: ('MGAB', 'Dodgers')
# 2.test.out+S09R01E4.test.csv@3.out: ('MGAB', 'Daphnet')
# 4.test.out+stb-19.test.out: ('MGAB', 'SensorScope')
# genesis-anomalies.test.csv@6.out+Yahoo_A2synthetic_72_data.out: ('Genesis', 'YAHOO')
# genesis-anomalies.test.csv@6.out+S4-ADL4.test.csv@120.out: ('Genesis', 'OPPORTUNITY')
# genesis-anomalies.test.csv@6.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('Genesis', 'GHL')
# genesis-anomalies.test.csv@6.out+MBA_ECG801_data.out: ('Genesis', 'ECG')
# genesis-anomalies.test.csv@6.out+machine-3-6.test.csv@9.out: ('Genesis', 'SMD')
# genesis-anomalies.test.csv@6.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('Genesis', 'IOPS')
# genesis-anomalies.test.csv@6.out+room-occupancy-0.test.csv@3.out: ('Genesis', 'Occupancy')
# genesis-anomalies.test.csv@6.out+NAB_data_CloudWatch_12.out: ('Genesis', 'NAB')
# genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('Genesis', 'Dodgers')
# genesis-anomalies.test.csv@6.out+S03R03E4.test.csv@2.out: ('Genesis', 'Daphnet')
# genesis-anomalies.test.csv@6.out+stb-19.test.out: ('Genesis', 'SensorScope')
# Yahoo_A2synthetic_72_data.out+S4-ADL3.test.csv@124.out: ('YAHOO', 'OPPORTUNITY')
# Yahoo_A2synthetic_72_data.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('YAHOO', 'GHL')
# Yahoo_A2synthetic_72_data.out+MBA_ECG14046_data_38.out: ('YAHOO', 'ECG')
# Yahoo_A2synthetic_72_data.out+machine-3-7.test.csv@7.out: ('YAHOO', 'SMD')
# Yahoo_A2synthetic_72_data.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('YAHOO', 'IOPS')
# Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out: ('YAHOO', 'Occupancy')
# Yahoo_A2synthetic_72_data.out+NAB_data_KnownCause_6.out: ('YAHOO', 'NAB')
# Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out: ('YAHOO', 'Dodgers')
# Yahoo_A2synthetic_72_data.out+S01R02E0.test.csv@1.out: ('YAHOO', 'Daphnet')
# Yahoo_A2synthetic_72_data.out+stb-19.test.out: ('YAHOO', 'SensorScope')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('OPPORTUNITY', 'GHL')
# S4-ADL3.test.csv@124.out+MBA_ECG801_data.out: ('OPPORTUNITY', 'ECG')
# S4-ADL3.test.csv@124.out+machine-2-8.test.csv@7.out: ('OPPORTUNITY', 'SMD')
# S4-ADL4.test.csv@120.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('OPPORTUNITY', 'IOPS')
# S4-ADL4.test.csv@120.out+room-occupancy-0.test.csv@3.out: ('OPPORTUNITY', 'Occupancy')
# S4-ADL3.test.csv@124.out+NAB_data_KnownCause_6.out: ('OPPORTUNITY', 'NAB')
# S4-ADL3.test.csv@124.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'Dodgers')
# S4-ADL3.test.csv@124.out+S03R03E4.test.csv@2.out: ('OPPORTUNITY', 'Daphnet')
# S4-ADL3.test.csv@124.out+stb-19.test.out: ('OPPORTUNITY', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out: ('GHL', 'ECG')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-7.test.csv@7.out: ('GHL', 'SMD')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('GHL', 'IOPS')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('GHL', 'Occupancy')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_CloudWatch_12.out: ('GHL', 'NAB')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('GHL', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+S01R02E0.test.csv@1.out: ('GHL', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+stb-19.test.out: ('GHL', 'SensorScope')
# MBA_ECG801_data.out+machine-2-8.test.csv@7.out: ('ECG', 'SMD')
# MBA_ECG14046_data_38.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('ECG', 'IOPS')
# MBA_ECG801_data.out+room-occupancy-0.test.csv@3.out: ('ECG', 'Occupancy')
# MBA_ECG801_data.out+NAB_data_CloudWatch_12.out: ('ECG', 'NAB')
# MBA_ECG14046_data_38.out+101-freeway-traffic.test.out: ('ECG', 'Dodgers')
# MBA_ECG801_data.out+S01R02E0.test.csv@1.out: ('ECG', 'Daphnet')
# MBA_ECG14046_data_38.out+stb-19.test.out: ('ECG', 'SensorScope')
# machine-2-8.test.csv@7.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('SMD', 'IOPS')
# machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out: ('SMD', 'Occupancy')
# machine-3-6.test.csv@9.out+NAB_data_CloudWatch_12.out: ('SMD', 'NAB')
# machine-3-7.test.csv@7.out+101-freeway-traffic.test.out: ('SMD', 'Dodgers')
# machine-3-6.test.csv@9.out+S09R01E4.test.csv@3.out: ('SMD', 'Daphnet')
# machine-3-6.test.csv@9.out+stb-19.test.out: ('SMD', 'SensorScope')
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+room-occupancy-0.test.csv@3.out: ('IOPS', 'Occupancy')
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+NAB_data_CloudWatch_12.out: ('IOPS', 'NAB')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+101-freeway-traffic.test.out: ('IOPS', 'Dodgers')
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+S09R01E4.test.csv@3.out: ('IOPS', 'Daphnet')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+stb-19.test.out: ('IOPS', 'SensorScope')
# room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out: ('Occupancy', 'NAB')
# room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('Occupancy', 'Dodgers')
# room-occupancy-0.test.csv@3.out+S01R02E0.test.csv@1.out: ('Occupancy', 'Daphnet')
# room-occupancy-0.test.csv@3.out+stb-19.test.out: ('Occupancy', 'SensorScope')
# NAB_data_KnownCause_6.out+101-freeway-traffic.test.out: ('NAB', 'Dodgers')
# NAB_data_CloudWatch_12.out+S03R03E4.test.csv@2.out: ('NAB', 'Daphnet')
# NAB_data_KnownCause_6.out+stb-19.test.out: ('NAB', 'SensorScope')
# 101-freeway-traffic.test.out+S01R02E0.test.csv@1.out: ('Dodgers', 'Daphnet')
# 101-freeway-traffic.test.out+stb-19.test.out: ('Dodgers', 'SensorScope')
# S09R01E4.test.csv@3.out+stb-19.test.out: ('Daphnet', 'SensorScope')
#
# Normality_3:
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+234.test.csv@1.out: ('NASA-MSL', 'KDD21', 'MITDB')
# F-8.test.out+083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out: ('NASA-MSL', 'KDD21', 'SVDB')
# F-8.test.out+083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+A-4.train.out: ('NASA-MSL', 'KDD21', 'NASA-SMAP')
# F-8.test.out+166_UCR_Anomaly_apneaecg_10000_12240_12308.out+2.test.out: ('NASA-MSL', 'KDD21', 'MGAB')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'KDD21', 'Genesis')
# F-8.test.out+166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'KDD21', 'YAHOO')
# F-8.test.out+083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'KDD21', 'OPPORTUNITY')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'KDD21', 'GHL')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'KDD21', 'ECG')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+machine-3-6.test.csv@9.out: ('NASA-MSL', 'KDD21', 'SMD')
# F-8.test.out+083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('NASA-MSL', 'KDD21', 'IOPS')
# F-8.test.out+166_UCR_Anomaly_apneaecg_10000_12240_12308.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'KDD21', 'Occupancy')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'KDD21', 'NAB')
# F-8.test.out+166_UCR_Anomaly_apneaecg_10000_12240_12308.out+101-freeway-traffic.test.out: ('NASA-MSL', 'KDD21', 'Dodgers')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'KDD21', 'Daphnet')
# F-8.test.out+242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+stb-19.test.out: ('NASA-MSL', 'KDD21', 'SensorScope')
# F-8.test.out+234.test.csv@1.out+893.test.csv@2.out: ('NASA-MSL', 'MITDB', 'SVDB')
# F-8.test.out+234.test.csv@1.out+A-9.test.out: ('NASA-MSL', 'MITDB', 'NASA-SMAP')
# F-8.test.out+234.test.csv@1.out+4.test.out: ('NASA-MSL', 'MITDB', 'MGAB')
# F-8.test.out+223.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'MITDB', 'Genesis')
# F-8.test.out+234.test.csv@1.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'MITDB', 'YAHOO')
# F-8.test.out+223.test.csv@2.out+S4-ADL4.test.csv@120.out: ('NASA-MSL', 'MITDB', 'OPPORTUNITY')
# F-8.test.out+223.test.csv@2.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'MITDB', 'GHL')
# F-8.test.out+223.test.csv@2.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'MITDB', 'ECG')
# F-8.test.out+234.test.csv@1.out+machine-2-8.test.csv@7.out: ('NASA-MSL', 'MITDB', 'SMD')
# F-8.test.out+223.test.csv@2.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'MITDB', 'IOPS')
# F-8.test.out+234.test.csv@1.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'MITDB', 'Occupancy')
# F-8.test.out+223.test.csv@2.out+NAB_data_CloudWatch_12.out: ('NASA-MSL', 'MITDB', 'NAB')
# F-8.test.out+234.test.csv@1.out+101-freeway-traffic.test.out: ('NASA-MSL', 'MITDB', 'Dodgers')
# F-8.test.out+234.test.csv@1.out+S01R02E0.test.csv@1.out: ('NASA-MSL', 'MITDB', 'Daphnet')
# F-8.test.out+223.test.csv@2.out+stb-19.test.out: ('NASA-MSL', 'MITDB', 'SensorScope')
# F-8.test.out+893.test.csv@2.out+A-9.test.out: ('NASA-MSL', 'SVDB', 'NASA-SMAP')
# F-8.test.out+893.test.csv@2.out+4.test.out: ('NASA-MSL', 'SVDB', 'MGAB')
# F-8.test.out+893.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'SVDB', 'Genesis')
# F-8.test.out+893.test.csv@2.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'SVDB', 'YAHOO')
# F-8.test.out+893.test.csv@2.out+S4-ADL4.test.csv@120.out: ('NASA-MSL', 'SVDB', 'OPPORTUNITY')
# F-8.test.out+893.test.csv@2.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'SVDB', 'GHL')
# F-8.test.out+893.test.csv@2.out+MBA_ECG801_data.out: ('NASA-MSL', 'SVDB', 'ECG')
# F-8.test.out+893.test.csv@2.out+machine-3-6.test.csv@9.out: ('NASA-MSL', 'SVDB', 'SMD')
# F-8.test.out+893.test.csv@2.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('NASA-MSL', 'SVDB', 'IOPS')
# F-8.test.out+893.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'SVDB', 'Occupancy')
# F-8.test.out+893.test.csv@2.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'SVDB', 'NAB')
# F-8.test.out+893.test.csv@2.out+101-freeway-traffic.test.out: ('NASA-MSL', 'SVDB', 'Dodgers')
# F-8.test.out+893.test.csv@2.out+S03R03E4.test.csv@2.out: ('NASA-MSL', 'SVDB', 'Daphnet')
# F-8.test.out+893.test.csv@2.out+stb-19.test.out: ('NASA-MSL', 'SVDB', 'SensorScope')
# F-8.test.out+A-4.train.out+4.test.out: ('NASA-MSL', 'NASA-SMAP', 'MGAB')
# F-8.test.out+A-4.train.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'NASA-SMAP', 'Genesis')
# F-8.test.out+A-4.train.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'NASA-SMAP', 'YAHOO')
# F-8.test.out+D-5.train.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'NASA-SMAP', 'OPPORTUNITY')
# F-8.test.out+A-9.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'NASA-SMAP', 'GHL')
# F-8.test.out+D-5.train.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'NASA-SMAP', 'ECG')
# F-8.test.out+A-4.train.out+machine-3-6.test.csv@9.out: ('NASA-MSL', 'NASA-SMAP', 'SMD')
# F-8.test.out+D-5.train.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'NASA-SMAP', 'IOPS')
# F-8.test.out+D-5.train.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'NASA-SMAP', 'Occupancy')
# F-8.test.out+A-4.train.out+NAB_data_CloudWatch_12.out: ('NASA-MSL', 'NASA-SMAP', 'NAB')
# F-8.test.out+D-5.train.out+101-freeway-traffic.test.out: ('NASA-MSL', 'NASA-SMAP', 'Dodgers')
# F-8.test.out+A-4.train.out+S01R02E0.test.csv@1.out: ('NASA-MSL', 'NASA-SMAP', 'Daphnet')
# F-8.test.out+A-4.train.out+stb-19.test.out: ('NASA-MSL', 'NASA-SMAP', 'SensorScope')
# F-8.test.out+4.test.out+genesis-anomalies.test.csv@6.out: ('NASA-MSL', 'MGAB', 'Genesis')
# F-8.test.out+4.test.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'MGAB', 'YAHOO')
# F-8.test.out+2.test.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'MGAB', 'OPPORTUNITY')
# F-8.test.out+4.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'MGAB', 'GHL')
# F-8.test.out+4.test.out+MBA_ECG801_data.out: ('NASA-MSL', 'MGAB', 'ECG')
# F-8.test.out+2.test.out+machine-2-8.test.csv@7.out: ('NASA-MSL', 'MGAB', 'SMD')
# F-8.test.out+4.test.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'MGAB', 'IOPS')
# F-8.test.out+2.test.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'MGAB', 'Occupancy')
# F-8.test.out+2.test.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'MGAB', 'NAB')
# F-8.test.out+2.test.out+101-freeway-traffic.test.out: ('NASA-MSL', 'MGAB', 'Dodgers')
# F-8.test.out+2.test.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'MGAB', 'Daphnet')
# F-8.test.out+4.test.out+stb-19.test.out: ('NASA-MSL', 'MGAB', 'SensorScope')
# F-8.test.out+genesis-anomalies.test.csv@6.out+Yahoo_A2synthetic_72_data.out: ('NASA-MSL', 'Genesis', 'YAHOO')
# F-8.test.out+genesis-anomalies.test.csv@6.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'Genesis', 'OPPORTUNITY')
# F-8.test.out+genesis-anomalies.test.csv@6.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'Genesis', 'GHL')
# F-8.test.out+genesis-anomalies.test.csv@6.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'Genesis', 'ECG')
# F-8.test.out+genesis-anomalies.test.csv@6.out+machine-3-6.test.csv@9.out: ('NASA-MSL', 'Genesis', 'SMD')
# F-8.test.out+genesis-anomalies.test.csv@6.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('NASA-MSL', 'Genesis', 'IOPS')
# F-8.test.out+genesis-anomalies.test.csv@6.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'Genesis', 'Occupancy')
# F-8.test.out+genesis-anomalies.test.csv@6.out+NAB_data_CloudWatch_12.out: ('NASA-MSL', 'Genesis', 'NAB')
# F-8.test.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('NASA-MSL', 'Genesis', 'Dodgers')
# F-8.test.out+genesis-anomalies.test.csv@6.out+S03R03E4.test.csv@2.out: ('NASA-MSL', 'Genesis', 'Daphnet')
# F-8.test.out+genesis-anomalies.test.csv@6.out+stb-19.test.out: ('NASA-MSL', 'Genesis', 'SensorScope')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+S4-ADL3.test.csv@124.out: ('NASA-MSL', 'YAHOO', 'OPPORTUNITY')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'YAHOO', 'GHL')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+MBA_ECG801_data.out: ('NASA-MSL', 'YAHOO', 'ECG')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+machine-2-8.test.csv@7.out: ('NASA-MSL', 'YAHOO', 'SMD')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('NASA-MSL', 'YAHOO', 'IOPS')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'YAHOO', 'Occupancy')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'YAHOO', 'NAB')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out: ('NASA-MSL', 'YAHOO', 'Dodgers')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+S01R02E0.test.csv@1.out: ('NASA-MSL', 'YAHOO', 'Daphnet')
# F-8.test.out+Yahoo_A2synthetic_72_data.out+stb-19.test.out: ('NASA-MSL', 'YAHOO', 'SensorScope')
# F-8.test.out+S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('NASA-MSL', 'OPPORTUNITY', 'GHL')
# F-8.test.out+S4-ADL3.test.csv@124.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'OPPORTUNITY', 'ECG')
# F-8.test.out+S4-ADL3.test.csv@124.out+machine-2-8.test.csv@7.out: ('NASA-MSL', 'OPPORTUNITY', 'SMD')
# F-8.test.out+S4-ADL3.test.csv@124.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'OPPORTUNITY', 'IOPS')
# F-8.test.out+S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'OPPORTUNITY', 'Occupancy')
# F-8.test.out+S4-ADL3.test.csv@124.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'OPPORTUNITY', 'NAB')
# F-8.test.out+S4-ADL3.test.csv@124.out+101-freeway-traffic.test.out: ('NASA-MSL', 'OPPORTUNITY', 'Dodgers')
# F-8.test.out+S4-ADL4.test.csv@120.out+S01R02E0.test.csv@1.out: ('NASA-MSL', 'OPPORTUNITY', 'Daphnet')
# F-8.test.out+S4-ADL3.test.csv@124.out+stb-19.test.out: ('NASA-MSL', 'OPPORTUNITY', 'SensorScope')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG14046_data_38.out: ('NASA-MSL', 'GHL', 'ECG')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-7.test.csv@7.out: ('NASA-MSL', 'GHL', 'SMD')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'GHL', 'IOPS')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'GHL', 'Occupancy')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'GHL', 'NAB')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('NASA-MSL', 'GHL', 'Dodgers')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+S03R03E4.test.csv@2.out: ('NASA-MSL', 'GHL', 'Daphnet')
# F-8.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+stb-19.test.out: ('NASA-MSL', 'GHL', 'SensorScope')
# F-8.test.out+MBA_ECG801_data.out+machine-3-6.test.csv@9.out: ('NASA-MSL', 'ECG', 'SMD')
# F-8.test.out+MBA_ECG14046_data_38.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('NASA-MSL', 'ECG', 'IOPS')
# F-8.test.out+MBA_ECG801_data.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'ECG', 'Occupancy')
# F-8.test.out+MBA_ECG801_data.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'ECG', 'NAB')
# F-8.test.out+MBA_ECG801_data.out+101-freeway-traffic.test.out: ('NASA-MSL', 'ECG', 'Dodgers')
# F-8.test.out+MBA_ECG801_data.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'ECG', 'Daphnet')
# F-8.test.out+MBA_ECG14046_data_38.out+stb-19.test.out: ('NASA-MSL', 'ECG', 'SensorScope')
# F-8.test.out+machine-3-7.test.csv@7.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('NASA-MSL', 'SMD', 'IOPS')
# F-8.test.out+machine-3-6.test.csv@9.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'SMD', 'Occupancy')
# F-8.test.out+machine-3-7.test.csv@7.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'SMD', 'NAB')
# F-8.test.out+machine-3-7.test.csv@7.out+101-freeway-traffic.test.out: ('NASA-MSL', 'SMD', 'Dodgers')
# F-8.test.out+machine-3-6.test.csv@9.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'SMD', 'Daphnet')
# F-8.test.out+machine-3-6.test.csv@9.out+stb-19.test.out: ('NASA-MSL', 'SMD', 'SensorScope')
# F-8.test.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'IOPS', 'Occupancy')
# F-8.test.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+NAB_data_KnownCause_6.out: ('NASA-MSL', 'IOPS', 'NAB')
# F-8.test.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+101-freeway-traffic.test.out: ('NASA-MSL', 'IOPS', 'Dodgers')
# F-8.test.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+S09R01E4.test.csv@3.out: ('NASA-MSL', 'IOPS', 'Daphnet')
# F-8.test.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+stb-19.test.out: ('NASA-MSL', 'IOPS', 'SensorScope')
# F-8.test.out+room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out: ('NASA-MSL', 'Occupancy', 'NAB')
# F-8.test.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('NASA-MSL', 'Occupancy', 'Dodgers')
# F-8.test.out+room-occupancy-0.test.csv@3.out+S03R03E4.test.csv@2.out: ('NASA-MSL', 'Occupancy', 'Daphnet')
# F-8.test.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('NASA-MSL', 'Occupancy', 'SensorScope')
# F-8.test.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('NASA-MSL', 'NAB', 'Dodgers')
# F-8.test.out+NAB_data_KnownCause_6.out+S01R02E0.test.csv@1.out: ('NASA-MSL', 'NAB', 'Daphnet')
# F-8.test.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('NASA-MSL', 'NAB', 'SensorScope')
# F-8.test.out+101-freeway-traffic.test.out+S03R03E4.test.csv@2.out: ('NASA-MSL', 'Dodgers', 'Daphnet')
# F-8.test.out+101-freeway-traffic.test.out+stb-19.test.out: ('NASA-MSL', 'Dodgers', 'SensorScope')
# F-8.test.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('NASA-MSL', 'Daphnet', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+223.test.csv@2.out+893.test.csv@2.out: ('KDD21', 'MITDB', 'SVDB')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+234.test.csv@1.out+D-5.train.out: ('KDD21', 'MITDB', 'NASA-SMAP')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+223.test.csv@2.out+2.test.out: ('KDD21', 'MITDB', 'MGAB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+223.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'MITDB', 'Genesis')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+234.test.csv@1.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'MITDB', 'YAHOO')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+223.test.csv@2.out+S4-ADL3.test.csv@124.out: ('KDD21', 'MITDB', 'OPPORTUNITY')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+234.test.csv@1.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'MITDB', 'GHL')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+234.test.csv@1.out+MBA_ECG14046_data_38.out: ('KDD21', 'MITDB', 'ECG')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+223.test.csv@2.out+machine-3-6.test.csv@9.out: ('KDD21', 'MITDB', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+223.test.csv@2.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('KDD21', 'MITDB', 'IOPS')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+223.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'MITDB', 'Occupancy')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+234.test.csv@1.out+NAB_data_KnownCause_6.out: ('KDD21', 'MITDB', 'NAB')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+234.test.csv@1.out+101-freeway-traffic.test.out: ('KDD21', 'MITDB', 'Dodgers')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+223.test.csv@2.out+S03R03E4.test.csv@2.out: ('KDD21', 'MITDB', 'Daphnet')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+234.test.csv@1.out+stb-19.test.out: ('KDD21', 'MITDB', 'SensorScope')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+893.test.csv@2.out+D-5.train.out: ('KDD21', 'SVDB', 'NASA-SMAP')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+2.test.out: ('KDD21', 'SVDB', 'MGAB')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+893.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'SVDB', 'Genesis')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'SVDB', 'YAHOO')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+S4-ADL4.test.csv@120.out: ('KDD21', 'SVDB', 'OPPORTUNITY')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'SVDB', 'GHL')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+MBA_ECG801_data.out: ('KDD21', 'SVDB', 'ECG')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+machine-3-7.test.csv@7.out: ('KDD21', 'SVDB', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+893.test.csv@2.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('KDD21', 'SVDB', 'IOPS')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+893.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'SVDB', 'Occupancy')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+893.test.csv@2.out+NAB_data_KnownCause_6.out: ('KDD21', 'SVDB', 'NAB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+101-freeway-traffic.test.out: ('KDD21', 'SVDB', 'Dodgers')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+893.test.csv@2.out+S03R03E4.test.csv@2.out: ('KDD21', 'SVDB', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+893.test.csv@2.out+stb-19.test.out: ('KDD21', 'SVDB', 'SensorScope')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+A-9.test.out+4.test.out: ('KDD21', 'NASA-SMAP', 'MGAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+A-9.test.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'NASA-SMAP', 'Genesis')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+D-5.train.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'NASA-SMAP', 'YAHOO')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+A-9.test.out+S4-ADL3.test.csv@124.out: ('KDD21', 'NASA-SMAP', 'OPPORTUNITY')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+D-5.train.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'NASA-SMAP', 'GHL')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+A-4.train.out+MBA_ECG14046_data_38.out: ('KDD21', 'NASA-SMAP', 'ECG')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+D-5.train.out+machine-3-6.test.csv@9.out: ('KDD21', 'NASA-SMAP', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+A-4.train.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('KDD21', 'NASA-SMAP', 'IOPS')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+D-5.train.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'NASA-SMAP', 'Occupancy')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+D-5.train.out+NAB_data_KnownCause_6.out: ('KDD21', 'NASA-SMAP', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+A-4.train.out+101-freeway-traffic.test.out: ('KDD21', 'NASA-SMAP', 'Dodgers')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+A-9.test.out+S01R02E0.test.csv@1.out: ('KDD21', 'NASA-SMAP', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+A-9.test.out+stb-19.test.out: ('KDD21', 'NASA-SMAP', 'SensorScope')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+2.test.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'MGAB', 'Genesis')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+2.test.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'MGAB', 'YAHOO')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+2.test.out+S4-ADL3.test.csv@124.out: ('KDD21', 'MGAB', 'OPPORTUNITY')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+2.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'MGAB', 'GHL')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+2.test.out+MBA_ECG801_data.out: ('KDD21', 'MGAB', 'ECG')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+2.test.out+machine-3-6.test.csv@9.out: ('KDD21', 'MGAB', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+4.test.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('KDD21', 'MGAB', 'IOPS')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+4.test.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'MGAB', 'Occupancy')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+2.test.out+NAB_data_KnownCause_6.out: ('KDD21', 'MGAB', 'NAB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+2.test.out+101-freeway-traffic.test.out: ('KDD21', 'MGAB', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+2.test.out+S09R01E4.test.csv@3.out: ('KDD21', 'MGAB', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+4.test.out+stb-19.test.out: ('KDD21', 'MGAB', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out+Yahoo_A2synthetic_72_data.out: ('KDD21', 'Genesis', 'YAHOO')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out+S4-ADL4.test.csv@120.out: ('KDD21', 'Genesis', 'OPPORTUNITY')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+genesis-anomalies.test.csv@6.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'Genesis', 'GHL')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out+MBA_ECG14046_data_38.out: ('KDD21', 'Genesis', 'ECG')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out+machine-3-7.test.csv@7.out: ('KDD21', 'Genesis', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('KDD21', 'Genesis', 'IOPS')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'Genesis', 'Occupancy')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out+NAB_data_KnownCause_6.out: ('KDD21', 'Genesis', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('KDD21', 'Genesis', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out+S03R03E4.test.csv@2.out: ('KDD21', 'Genesis', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+genesis-anomalies.test.csv@6.out+stb-19.test.out: ('KDD21', 'Genesis', 'SensorScope')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+Yahoo_A2synthetic_72_data.out+S4-ADL4.test.csv@120.out: ('KDD21', 'YAHOO', 'OPPORTUNITY')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'YAHOO', 'GHL')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+Yahoo_A2synthetic_72_data.out+MBA_ECG801_data.out: ('KDD21', 'YAHOO', 'ECG')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+Yahoo_A2synthetic_72_data.out+machine-3-6.test.csv@9.out: ('KDD21', 'YAHOO', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('KDD21', 'YAHOO', 'IOPS')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'YAHOO', 'Occupancy')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+Yahoo_A2synthetic_72_data.out+NAB_data_CloudWatch_12.out: ('KDD21', 'YAHOO', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out: ('KDD21', 'YAHOO', 'Dodgers')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+Yahoo_A2synthetic_72_data.out+S03R03E4.test.csv@2.out: ('KDD21', 'YAHOO', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+Yahoo_A2synthetic_72_data.out+stb-19.test.out: ('KDD21', 'YAHOO', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('KDD21', 'OPPORTUNITY', 'GHL')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S4-ADL3.test.csv@124.out+MBA_ECG801_data.out: ('KDD21', 'OPPORTUNITY', 'ECG')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S4-ADL3.test.csv@124.out+machine-3-7.test.csv@7.out: ('KDD21', 'OPPORTUNITY', 'SMD')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S4-ADL4.test.csv@120.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('KDD21', 'OPPORTUNITY', 'IOPS')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'OPPORTUNITY', 'Occupancy')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S4-ADL4.test.csv@120.out+NAB_data_CloudWatch_12.out: ('KDD21', 'OPPORTUNITY', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S4-ADL4.test.csv@120.out+101-freeway-traffic.test.out: ('KDD21', 'OPPORTUNITY', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S4-ADL4.test.csv@120.out+S03R03E4.test.csv@2.out: ('KDD21', 'OPPORTUNITY', 'Daphnet')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+S4-ADL4.test.csv@120.out+stb-19.test.out: ('KDD21', 'OPPORTUNITY', 'SensorScope')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out: ('KDD21', 'GHL', 'ECG')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-6.test.csv@9.out: ('KDD21', 'GHL', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('KDD21', 'GHL', 'IOPS')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'GHL', 'Occupancy')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_KnownCause_6.out: ('KDD21', 'GHL', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('KDD21', 'GHL', 'Dodgers')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+S01R02E0.test.csv@1.out: ('KDD21', 'GHL', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+stb-19.test.out: ('KDD21', 'GHL', 'SensorScope')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+MBA_ECG14046_data_38.out+machine-3-7.test.csv@7.out: ('KDD21', 'ECG', 'SMD')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+MBA_ECG801_data.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('KDD21', 'ECG', 'IOPS')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+MBA_ECG801_data.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'ECG', 'Occupancy')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+MBA_ECG801_data.out+NAB_data_CloudWatch_12.out: ('KDD21', 'ECG', 'NAB')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+MBA_ECG14046_data_38.out+101-freeway-traffic.test.out: ('KDD21', 'ECG', 'Dodgers')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+MBA_ECG801_data.out+S03R03E4.test.csv@2.out: ('KDD21', 'ECG', 'Daphnet')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+MBA_ECG801_data.out+stb-19.test.out: ('KDD21', 'ECG', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+machine-2-8.test.csv@7.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('KDD21', 'SMD', 'IOPS')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'SMD', 'Occupancy')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+machine-3-6.test.csv@9.out+NAB_data_CloudWatch_12.out: ('KDD21', 'SMD', 'NAB')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+machine-3-7.test.csv@7.out+101-freeway-traffic.test.out: ('KDD21', 'SMD', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+machine-2-8.test.csv@7.out+S09R01E4.test.csv@3.out: ('KDD21', 'SMD', 'Daphnet')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+machine-3-6.test.csv@9.out+stb-19.test.out: ('KDD21', 'SMD', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'IOPS', 'Occupancy')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+NAB_data_CloudWatch_12.out: ('KDD21', 'IOPS', 'NAB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+101-freeway-traffic.test.out: ('KDD21', 'IOPS', 'Dodgers')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+S03R03E4.test.csv@2.out: ('KDD21', 'IOPS', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+stb-19.test.out: ('KDD21', 'IOPS', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+room-occupancy-0.test.csv@3.out+NAB_data_KnownCause_6.out: ('KDD21', 'Occupancy', 'NAB')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('KDD21', 'Occupancy', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+room-occupancy-0.test.csv@3.out+S09R01E4.test.csv@3.out: ('KDD21', 'Occupancy', 'Daphnet')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('KDD21', 'Occupancy', 'SensorScope')
# 083_UCR_Anomaly_DISTORTEDresperation9_38000_143411_143511.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('KDD21', 'NAB', 'Dodgers')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+NAB_data_KnownCause_6.out+S01R02E0.test.csv@1.out: ('KDD21', 'NAB', 'Daphnet')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('KDD21', 'NAB', 'SensorScope')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+101-freeway-traffic.test.out+S03R03E4.test.csv@2.out: ('KDD21', 'Dodgers', 'Daphnet')
# 166_UCR_Anomaly_apneaecg_10000_12240_12308.out+101-freeway-traffic.test.out+stb-19.test.out: ('KDD21', 'Dodgers', 'SensorScope')
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+S09R01E4.test.csv@3.out+stb-19.test.out: ('KDD21', 'Daphnet', 'SensorScope')
# 223.test.csv@2.out+893.test.csv@2.out+D-5.train.out: ('MITDB', 'SVDB', 'NASA-SMAP')
# 234.test.csv@1.out+893.test.csv@2.out+2.test.out: ('MITDB', 'SVDB', 'MGAB')
# 234.test.csv@1.out+893.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'SVDB', 'Genesis')
# 223.test.csv@2.out+893.test.csv@2.out+Yahoo_A2synthetic_72_data.out: ('MITDB', 'SVDB', 'YAHOO')
# 223.test.csv@2.out+893.test.csv@2.out+S4-ADL4.test.csv@120.out: ('MITDB', 'SVDB', 'OPPORTUNITY')
# 223.test.csv@2.out+893.test.csv@2.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MITDB', 'SVDB', 'GHL')
# 234.test.csv@1.out+893.test.csv@2.out+MBA_ECG14046_data_38.out: ('MITDB', 'SVDB', 'ECG')
# 223.test.csv@2.out+893.test.csv@2.out+machine-2-8.test.csv@7.out: ('MITDB', 'SVDB', 'SMD')
# 234.test.csv@1.out+893.test.csv@2.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out: ('MITDB', 'SVDB', 'IOPS')
# 223.test.csv@2.out+893.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'SVDB', 'Occupancy')
# 234.test.csv@1.out+893.test.csv@2.out+NAB_data_CloudWatch_12.out: ('MITDB', 'SVDB', 'NAB')
# 223.test.csv@2.out+893.test.csv@2.out+101-freeway-traffic.test.out: ('MITDB', 'SVDB', 'Dodgers')
# 234.test.csv@1.out+893.test.csv@2.out+S03R03E4.test.csv@2.out: ('MITDB', 'SVDB', 'Daphnet')
# 223.test.csv@2.out+893.test.csv@2.out+stb-19.test.out: ('MITDB', 'SVDB', 'SensorScope')
# 223.test.csv@2.out+A-4.train.out+2.test.out: ('MITDB', 'NASA-SMAP', 'MGAB')
# 223.test.csv@2.out+A-9.test.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'NASA-SMAP', 'Genesis')
# 223.test.csv@2.out+D-5.train.out+Yahoo_A2synthetic_72_data.out: ('MITDB', 'NASA-SMAP', 'YAHOO')
# 223.test.csv@2.out+A-4.train.out+S4-ADL3.test.csv@124.out: ('MITDB', 'NASA-SMAP', 'OPPORTUNITY')
# 223.test.csv@2.out+D-5.train.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MITDB', 'NASA-SMAP', 'GHL')
# 223.test.csv@2.out+D-5.train.out+MBA_ECG14046_data_38.out: ('MITDB', 'NASA-SMAP', 'ECG')
# 223.test.csv@2.out+A-4.train.out+machine-3-6.test.csv@9.out: ('MITDB', 'NASA-SMAP', 'SMD')
# 223.test.csv@2.out+D-5.train.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('MITDB', 'NASA-SMAP', 'IOPS')
# 223.test.csv@2.out+A-9.test.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'NASA-SMAP', 'Occupancy')
# 234.test.csv@1.out+A-4.train.out+NAB_data_KnownCause_6.out: ('MITDB', 'NASA-SMAP', 'NAB')
# 223.test.csv@2.out+D-5.train.out+101-freeway-traffic.test.out: ('MITDB', 'NASA-SMAP', 'Dodgers')
# 234.test.csv@1.out+A-9.test.out+S01R02E0.test.csv@1.out: ('MITDB', 'NASA-SMAP', 'Daphnet')
# 234.test.csv@1.out+D-5.train.out+stb-19.test.out: ('MITDB', 'NASA-SMAP', 'SensorScope')
# 234.test.csv@1.out+2.test.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'MGAB', 'Genesis')
# 223.test.csv@2.out+2.test.out+Yahoo_A2synthetic_72_data.out: ('MITDB', 'MGAB', 'YAHOO')
# 223.test.csv@2.out+2.test.out+S4-ADL3.test.csv@124.out: ('MITDB', 'MGAB', 'OPPORTUNITY')
# 234.test.csv@1.out+4.test.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MITDB', 'MGAB', 'GHL')
# 223.test.csv@2.out+2.test.out+MBA_ECG801_data.out: ('MITDB', 'MGAB', 'ECG')
# 223.test.csv@2.out+4.test.out+machine-3-7.test.csv@7.out: ('MITDB', 'MGAB', 'SMD')
# 234.test.csv@1.out+2.test.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('MITDB', 'MGAB', 'IOPS')
# 223.test.csv@2.out+4.test.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'MGAB', 'Occupancy')
# 234.test.csv@1.out+2.test.out+NAB_data_CloudWatch_12.out: ('MITDB', 'MGAB', 'NAB')
# 223.test.csv@2.out+2.test.out+101-freeway-traffic.test.out: ('MITDB', 'MGAB', 'Dodgers')
# 234.test.csv@1.out+4.test.out+S03R03E4.test.csv@2.out: ('MITDB', 'MGAB', 'Daphnet')
# 234.test.csv@1.out+2.test.out+stb-19.test.out: ('MITDB', 'MGAB', 'SensorScope')
# 223.test.csv@2.out+genesis-anomalies.test.csv@6.out+Yahoo_A2synthetic_72_data.out: ('MITDB', 'Genesis', 'YAHOO')
# 223.test.csv@2.out+genesis-anomalies.test.csv@6.out+S4-ADL3.test.csv@124.out: ('MITDB', 'Genesis', 'OPPORTUNITY')
# 223.test.csv@2.out+genesis-anomalies.test.csv@6.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out: ('MITDB', 'Genesis', 'GHL')
# ...
# Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('YAHOO', 'Occupancy', 'Dodgers')
# Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out+S03R03E4.test.csv@2.out: ('YAHOO', 'Occupancy', 'Daphnet')
# Yahoo_A2synthetic_72_data.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('YAHOO', 'Occupancy', 'SensorScope')
# Yahoo_A2synthetic_72_data.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('YAHOO', 'NAB', 'Dodgers')
# Yahoo_A2synthetic_72_data.out+NAB_data_KnownCause_6.out+S09R01E4.test.csv@3.out: ('YAHOO', 'NAB', 'Daphnet')
# Yahoo_A2synthetic_72_data.out+NAB_data_KnownCause_6.out+stb-19.test.out: ('YAHOO', 'NAB', 'SensorScope')
# Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out+S03R03E4.test.csv@2.out: ('YAHOO', 'Dodgers', 'Daphnet')
# Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out+stb-19.test.out: ('YAHOO', 'Dodgers', 'SensorScope')
# Yahoo_A2synthetic_72_data.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('YAHOO', 'Daphnet', 'SensorScope')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out: ('OPPORTUNITY', 'GHL', 'ECG')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-6.test.csv@9.out: ('OPPORTUNITY', 'GHL', 'SMD')
# S4-ADL4.test.csv@120.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('OPPORTUNITY', 'GHL', 'IOPS')
# S4-ADL4.test.csv@120.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('OPPORTUNITY', 'GHL', 'Occupancy')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_KnownCause_6.out: ('OPPORTUNITY', 'GHL', 'NAB')
# S4-ADL4.test.csv@120.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'GHL', 'Dodgers')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+S09R01E4.test.csv@3.out: ('OPPORTUNITY', 'GHL', 'Daphnet')
# S4-ADL3.test.csv@124.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+stb-19.test.out: ('OPPORTUNITY', 'GHL', 'SensorScope')
# S4-ADL4.test.csv@120.out+MBA_ECG14046_data_38.out+machine-3-7.test.csv@7.out: ('OPPORTUNITY', 'ECG', 'SMD')
# S4-ADL3.test.csv@124.out+MBA_ECG801_data.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('OPPORTUNITY', 'ECG', 'IOPS')
# S4-ADL3.test.csv@124.out+MBA_ECG14046_data_38.out+room-occupancy-0.test.csv@3.out: ('OPPORTUNITY', 'ECG', 'Occupancy')
# S4-ADL4.test.csv@120.out+MBA_ECG14046_data_38.out+NAB_data_KnownCause_6.out: ('OPPORTUNITY', 'ECG', 'NAB')
# S4-ADL3.test.csv@124.out+MBA_ECG801_data.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'ECG', 'Dodgers')
# S4-ADL3.test.csv@124.out+MBA_ECG14046_data_38.out+S01R02E0.test.csv@1.out: ('OPPORTUNITY', 'ECG', 'Daphnet')
# S4-ADL4.test.csv@120.out+MBA_ECG801_data.out+stb-19.test.out: ('OPPORTUNITY', 'ECG', 'SensorScope')
# S4-ADL3.test.csv@124.out+machine-3-6.test.csv@9.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('OPPORTUNITY', 'SMD', 'IOPS')
# S4-ADL4.test.csv@120.out+machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out: ('OPPORTUNITY', 'SMD', 'Occupancy')
# S4-ADL4.test.csv@120.out+machine-3-6.test.csv@9.out+NAB_data_CloudWatch_12.out: ('OPPORTUNITY', 'SMD', 'NAB')
# S4-ADL4.test.csv@120.out+machine-2-8.test.csv@7.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'SMD', 'Dodgers')
# S4-ADL4.test.csv@120.out+machine-3-7.test.csv@7.out+S03R03E4.test.csv@2.out: ('OPPORTUNITY', 'SMD', 'Daphnet')
# S4-ADL3.test.csv@124.out+machine-3-7.test.csv@7.out+stb-19.test.out: ('OPPORTUNITY', 'SMD', 'SensorScope')
# S4-ADL4.test.csv@120.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+room-occupancy-0.test.csv@3.out: ('OPPORTUNITY', 'IOPS', 'Occupancy')
# S4-ADL3.test.csv@124.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+NAB_data_KnownCause_6.out: ('OPPORTUNITY', 'IOPS', 'NAB')
# S4-ADL4.test.csv@120.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'IOPS', 'Dodgers')
# S4-ADL3.test.csv@124.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+S01R02E0.test.csv@1.out: ('OPPORTUNITY', 'IOPS', 'Daphnet')
# S4-ADL3.test.csv@124.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+stb-19.test.out: ('OPPORTUNITY', 'IOPS', 'SensorScope')
# S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out: ('OPPORTUNITY', 'Occupancy', 'NAB')
# S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'Occupancy', 'Dodgers')
# S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out+S01R02E0.test.csv@1.out: ('OPPORTUNITY', 'Occupancy', 'Daphnet')
# S4-ADL3.test.csv@124.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('OPPORTUNITY', 'Occupancy', 'SensorScope')
# S4-ADL4.test.csv@120.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'NAB', 'Dodgers')
# S4-ADL4.test.csv@120.out+NAB_data_KnownCause_6.out+S03R03E4.test.csv@2.out: ('OPPORTUNITY', 'NAB', 'Daphnet')
# S4-ADL4.test.csv@120.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('OPPORTUNITY', 'NAB', 'SensorScope')
# S4-ADL4.test.csv@120.out+101-freeway-traffic.test.out+S09R01E4.test.csv@3.out: ('OPPORTUNITY', 'Dodgers', 'Daphnet')
# S4-ADL3.test.csv@124.out+101-freeway-traffic.test.out+stb-19.test.out: ('OPPORTUNITY', 'Dodgers', 'SensorScope')
# S4-ADL3.test.csv@124.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('OPPORTUNITY', 'Daphnet', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out+machine-3-6.test.csv@9.out: ('GHL', 'ECG', 'SMD')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG14046_data_38.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ('GHL', 'ECG', 'IOPS')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG14046_data_38.out+room-occupancy-0.test.csv@3.out: ('GHL', 'ECG', 'Occupancy')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG14046_data_38.out+NAB_data_CloudWatch_12.out: ('GHL', 'ECG', 'NAB')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG14046_data_38.out+101-freeway-traffic.test.out: ('GHL', 'ECG', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out+S03R03E4.test.csv@2.out: ('GHL', 'ECG', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+MBA_ECG801_data.out+stb-19.test.out: ('GHL', 'ECG', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-2-8.test.csv@7.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('GHL', 'SMD', 'IOPS')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-2-8.test.csv@7.out+room-occupancy-0.test.csv@3.out: ('GHL', 'SMD', 'Occupancy')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-7.test.csv@7.out+NAB_data_CloudWatch_12.out: ('GHL', 'SMD', 'NAB')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-2-8.test.csv@7.out+101-freeway-traffic.test.out: ('GHL', 'SMD', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-7.test.csv@7.out+S09R01E4.test.csv@3.out: ('GHL', 'SMD', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-7.test.csv@7.out+stb-19.test.out: ('GHL', 'SMD', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+room-occupancy-0.test.csv@3.out: ('GHL', 'IOPS', 'Occupancy')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+NAB_data_KnownCause_6.out: ('GHL', 'IOPS', 'NAB')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+101-freeway-traffic.test.out: ('GHL', 'IOPS', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+S09R01E4.test.csv@3.out: ('GHL', 'IOPS', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+stb-19.test.out: ('GHL', 'IOPS', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out: ('GHL', 'Occupancy', 'NAB')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('GHL', 'Occupancy', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out+S09R01E4.test.csv@3.out: ('GHL', 'Occupancy', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('GHL', 'Occupancy', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_KnownCause_6.out+101-freeway-traffic.test.out: ('GHL', 'NAB', 'Dodgers')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_KnownCause_6.out+S01R02E0.test.csv@1.out: ('GHL', 'NAB', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('GHL', 'NAB', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out+S01R02E0.test.csv@1.out: ('GHL', 'Dodgers', 'Daphnet')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+101-freeway-traffic.test.out+stb-19.test.out: ('GHL', 'Dodgers', 'SensorScope')
# 05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+S09R01E4.test.csv@3.out+stb-19.test.out: ('GHL', 'Daphnet', 'SensorScope')
# MBA_ECG14046_data_38.out+machine-3-7.test.csv@7.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ('ECG', 'SMD', 'IOPS')
# MBA_ECG14046_data_38.out+machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out: ('ECG', 'SMD', 'Occupancy')
# MBA_ECG14046_data_38.out+machine-3-6.test.csv@9.out+NAB_data_KnownCause_6.out: ('ECG', 'SMD', 'NAB')
# MBA_ECG801_data.out+machine-2-8.test.csv@7.out+101-freeway-traffic.test.out: ('ECG', 'SMD', 'Dodgers')
# MBA_ECG14046_data_38.out+machine-2-8.test.csv@7.out+S01R02E0.test.csv@1.out: ('ECG', 'SMD', 'Daphnet')
# MBA_ECG14046_data_38.out+machine-2-8.test.csv@7.out+stb-19.test.out: ('ECG', 'SMD', 'SensorScope')
# MBA_ECG801_data.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+room-occupancy-0.test.csv@3.out: ('ECG', 'IOPS', 'Occupancy')
# MBA_ECG801_data.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+NAB_data_CloudWatch_12.out: ('ECG', 'IOPS', 'NAB')
# MBA_ECG14046_data_38.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+101-freeway-traffic.test.out: ('ECG', 'IOPS', 'Dodgers')
# MBA_ECG801_data.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+S09R01E4.test.csv@3.out: ('ECG', 'IOPS', 'Daphnet')
# MBA_ECG801_data.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+stb-19.test.out: ('ECG', 'IOPS', 'SensorScope')
# MBA_ECG14046_data_38.out+room-occupancy-0.test.csv@3.out+NAB_data_KnownCause_6.out: ('ECG', 'Occupancy', 'NAB')
# MBA_ECG14046_data_38.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('ECG', 'Occupancy', 'Dodgers')
# MBA_ECG801_data.out+room-occupancy-0.test.csv@3.out+S01R02E0.test.csv@1.out: ('ECG', 'Occupancy', 'Daphnet')
# MBA_ECG801_data.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('ECG', 'Occupancy', 'SensorScope')
# MBA_ECG14046_data_38.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('ECG', 'NAB', 'Dodgers')
# MBA_ECG14046_data_38.out+NAB_data_KnownCause_6.out+S09R01E4.test.csv@3.out: ('ECG', 'NAB', 'Daphnet')
# MBA_ECG14046_data_38.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('ECG', 'NAB', 'SensorScope')
# MBA_ECG801_data.out+101-freeway-traffic.test.out+S01R02E0.test.csv@1.out: ('ECG', 'Dodgers', 'Daphnet')
# MBA_ECG801_data.out+101-freeway-traffic.test.out+stb-19.test.out: ('ECG', 'Dodgers', 'SensorScope')
# MBA_ECG14046_data_38.out+S09R01E4.test.csv@3.out+stb-19.test.out: ('ECG', 'Daphnet', 'SensorScope')
# machine-2-8.test.csv@7.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+room-occupancy-0.test.csv@3.out: ('SMD', 'IOPS', 'Occupancy')
# machine-3-6.test.csv@9.out+KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+NAB_data_KnownCause_6.out: ('SMD', 'IOPS', 'NAB')
# machine-3-7.test.csv@7.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+101-freeway-traffic.test.out: ('SMD', 'IOPS', 'Dodgers')
# machine-2-8.test.csv@7.out+KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+S03R03E4.test.csv@2.out: ('SMD', 'IOPS', 'Daphnet')
# machine-3-6.test.csv@9.out+KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+stb-19.test.out: ('SMD', 'IOPS', 'SensorScope')
# machine-3-6.test.csv@9.out+room-occupancy-0.test.csv@3.out+NAB_data_KnownCause_6.out: ('SMD', 'Occupancy', 'NAB')
# machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('SMD', 'Occupancy', 'Dodgers')
# machine-2-8.test.csv@7.out+room-occupancy-0.test.csv@3.out+S09R01E4.test.csv@3.out: ('SMD', 'Occupancy', 'Daphnet')
# machine-3-7.test.csv@7.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('SMD', 'Occupancy', 'SensorScope')
# machine-3-7.test.csv@7.out+NAB_data_KnownCause_6.out+101-freeway-traffic.test.out: ('SMD', 'NAB', 'Dodgers')
# machine-3-6.test.csv@9.out+NAB_data_CloudWatch_12.out+S01R02E0.test.csv@1.out: ('SMD', 'NAB', 'Daphnet')
# machine-2-8.test.csv@7.out+NAB_data_KnownCause_6.out+stb-19.test.out: ('SMD', 'NAB', 'SensorScope')
# machine-3-6.test.csv@9.out+101-freeway-traffic.test.out+S03R03E4.test.csv@2.out: ('SMD', 'Dodgers', 'Daphnet')
# machine-3-6.test.csv@9.out+101-freeway-traffic.test.out+stb-19.test.out: ('SMD', 'Dodgers', 'SensorScope')
# machine-3-7.test.csv@7.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('SMD', 'Daphnet', 'SensorScope')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out: ('IOPS', 'Occupancy', 'NAB')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('IOPS', 'Occupancy', 'Dodgers')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+room-occupancy-0.test.csv@3.out+S03R03E4.test.csv@2.out: ('IOPS', 'Occupancy', 'Daphnet')
# KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+room-occupancy-0.test.csv@3.out+stb-19.test.out: ('IOPS', 'Occupancy', 'SensorScope')
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('IOPS', 'NAB', 'Dodgers')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+NAB_data_CloudWatch_12.out+S09R01E4.test.csv@3.out: ('IOPS', 'NAB', 'Daphnet')
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out+NAB_data_KnownCause_6.out+stb-19.test.out: ('IOPS', 'NAB', 'SensorScope')
# KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+101-freeway-traffic.test.out+S03R03E4.test.csv@2.out: ('IOPS', 'Dodgers', 'Daphnet')
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out+101-freeway-traffic.test.out+stb-19.test.out: ('IOPS', 'Dodgers', 'SensorScope')
# KPI-adb2fde9-8589-3f5b-a410-5fe14386c7af.train.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('IOPS', 'Daphnet', 'SensorScope')
# room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out+101-freeway-traffic.test.out: ('Occupancy', 'NAB', 'Dodgers')
# room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out+S09R01E4.test.csv@3.out: ('Occupancy', 'NAB', 'Daphnet')
# room-occupancy-0.test.csv@3.out+NAB_data_CloudWatch_12.out+stb-19.test.out: ('Occupancy', 'NAB', 'SensorScope')
# room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out+S09R01E4.test.csv@3.out: ('Occupancy', 'Dodgers', 'Daphnet')
# room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out+stb-19.test.out: ('Occupancy', 'Dodgers', 'SensorScope')
# room-occupancy-0.test.csv@3.out+S03R03E4.test.csv@2.out+stb-19.test.out: ('Occupancy', 'Daphnet', 'SensorScope')
# NAB_data_KnownCause_6.out+101-freeway-traffic.test.out+S09R01E4.test.csv@3.out: ('NAB', 'Dodgers', 'Daphnet')
# NAB_data_KnownCause_6.out+101-freeway-traffic.test.out+stb-19.test.out: ('NAB', 'Dodgers', 'SensorScope')
# NAB_data_CloudWatch_12.out+S09R01E4.test.csv@3.out+stb-19.test.out: ('NAB', 'Daphnet', 'SensorScope')
# 101-freeway-traffic.test.out+S01R02E0.test.csv@1.out+stb-19.test.out: ('Dodgers', 'Daphnet', 'SensorScope')

# %%
def create_combined_norm_dict(normality_1, normality_2, normality_3):
    combined_dict = {}
    counts = {"Normality_1": 0, "Normality_2": 0, "Normality_3": 0}

    # Adding from Normality_1
    for subfolder, files in normality_1.items():
        for file in files:
            if file not in combined_dict:
                combined_dict[file] = ["Normality_1", subfolder]
                counts["Normality_1"] += 1

    # Adding from Normality_2
    for key, subfolders in normality_2.items():
        if key not in combined_dict:
            combined_dict[key] = ["Normality_2", subfolders[0], subfolders[1]]
            counts["Normality_2"] += 1

    # Adding from Normality_3
    for key, subfolders in normality_3.items():
        if key not in combined_dict:
            combined_dict[key] = ["Normality_3", subfolders[0], subfolders[1], subfolders[2]]
            counts["Normality_3"] += 1

    return combined_dict, counts

# %%
combined_norm_dict, counts = create_combined_norm_dict(normality_1, normality_2, normality_3)

# %%
print("\nCounts of filenames from each normality:")
for normality, count in counts.items():
    print(f"{normality}: {count}")
# Out:
# Counts of filenames from each normality:
# Normality_1: 33
# Normality_2: 153
# Normality_3: 816

# %%
normality_1_count = 5
normality_2_count = 5
normality_3_count = 5

# %%
def create_predefined_dict(combined_dict, normality_1_count, normality_2_count, normality_3_count):
    predefined_dict = {"Normality_1": {}, "Normality_2": {}, "Normality_3": {}}
    
    # Extracting specific numbers of items from each normality type
    normality_1_items = [item for item in combined_dict.items() if item[1][0] == "Normality_1"]
    normality_2_items = [item for item in combined_dict.items() if item[1][0] == "Normality_2"]
    normality_3_items = [item for item in combined_dict.items() if item[1][0] == "Normality_3"]
    
    # Select predefined numbers of items
    selected_normality_1_items = random.sample(normality_1_items, min(normality_1_count, len(normality_1_items)))
    selected_normality_2_items = random.sample(normality_2_items, min(normality_2_count, len(normality_2_items)))
    selected_normality_3_items = random.sample(normality_3_items, min(normality_3_count, len(normality_3_items)))
    
    # Combine selected items into the predefined_dict
    predefined_dict["Normality_1"] = dict(selected_normality_1_items)
    predefined_dict["Normality_2"] = dict(selected_normality_2_items)
    predefined_dict["Normality_3"] = dict(selected_normality_3_items)
    
    # Combine all selected items into a single dictionary
    all_selected_items = selected_normality_1_items + selected_normality_2_items + selected_normality_3_items
    
    # Shuffle the combined selected items
    random.shuffle(all_selected_items)
    
    # Convert to a dictionary
    shuffled_dict = dict(all_selected_items)
    
    return shuffled_dict

# %%
predefined_shuffled_dict = create_predefined_dict(combined_norm_dict, normality_1_count, normality_2_count, normality_3_count)

# %%
print("Predefined Shuffled Dictionary:")
for key, value in predefined_shuffled_dict.items():
    print(f"{key}: {value}")
# Out:
# Predefined Shuffled Dictionary:
# room-occupancy-0.test.csv@3.out: ['Normality_1', 'Occupancy']
# Yahoo_A2synthetic_72_data.out+101-freeway-traffic.test.out: ['Normality_2', 'YAHOO', 'Dodgers']
# 893.test.csv@2.out+stb-19.test.out: ['Normality_2', 'SVDB', 'SensorScope']
# room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ['Normality_2', 'Occupancy', 'Dodgers']
# KPI-f0932edd-6400-3e63-9559-0a9860a1baa9.train.out: ['Normality_1', 'IOPS']
# Yahoo_A2synthetic_72_data.out+machine-3-6.test.csv@9.out+stb-19.test.out: ['Normality_3', 'YAHOO', 'SMD', 'SensorScope']
# 4.test.out+stb-19.test.out: ['Normality_2', 'MGAB', 'SensorScope']
# F-8.test.out+893.test.csv@2.out+room-occupancy-0.test.csv@3.out: ['Normality_3', 'NASA-MSL', 'SVDB', 'Occupancy']
# 242_UCR_Anomaly_tilt12744mtable_100000_104630_104890.out+05_Lev_fault_Temp_corr_seed_27_vars_23.test.csv@8.out+machine-3-6.test.csv@9.out: ['Normality_3', 'KDD21', 'GHL', 'SMD']
# Yahoo_A2synthetic_72_data.out+S4-ADL4.test.csv@120.out+NAB_data_CloudWatch_12.out: ['Normality_3', 'YAHOO', 'OPPORTUNITY', 'NAB']
# F-8.test.out: ['Normality_1', 'NASA-MSL']
# A-9.test.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ['Normality_3', 'NASA-SMAP', 'Occupancy', 'Dodgers']
# 893.test.csv@2.out+NAB_data_CloudWatch_12.out: ['Normality_2', 'SVDB', 'NAB']
# KPI-0efb375b-b902-3661-ab23-9a0bb799f4e3.test.out: ['Normality_1', 'IOPS']
# S4-ADL3.test.csv@124.out: ['Normality_1', 'OPPORTUNITY']

# %%
def create_files_and_new_dict(predefined_shuffled_dict, base_folder):
    new_dict = {}
    id_counter = 1

    for key, value in predefined_shuffled_dict.items():
        new_filename = f"ts{id_counter}"
        new_filepath = os.path.join(base_folder, new_filename)
        
        if value[0] == "Normality_1":
            subfolder = value[1]
            original_filepath = os.path.join(base_folder, subfolder, key)
            with open(original_filepath, 'r') as original_file:
                content = original_file.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_2":
            subfolder1, subfolder2 = value[1], value[2]
            file1, file2 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2:
                content = f1.read() + f2.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_3":
            subfolder1, subfolder2, subfolder3 = value[1], value[2], value[3]
            file1, file2, file3 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            filepath3 = os.path.join(base_folder, subfolder3, file3)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2, open(filepath3, 'r') as f3:
                content = f1.read() + f2.read() + f3.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        new_dict[new_filename] = value
        id_counter += 1
    
    return new_dict

# %%
def create_files_and_new_dict(predefined_shuffled_dict, base_folder):
    new_dict = {}
    id_counter = 1

    for key, value in predefined_shuffled_dict.items():
        new_filename = f"ts{id_counter}"
        new_filepath = os.path.join('TS-Data-Files/', new_filename)
        
        if value[0] == "Normality_1":
            subfolder = value[1]
            original_filepath = os.path.join(base_folder, subfolder, key)
            with open(original_filepath, 'r') as original_file:
                content = original_file.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_2":
            subfolder1, subfolder2 = value[1], value[2]
            file1, file2 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2:
                content = f1.read() + f2.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_3":
            subfolder1, subfolder2, subfolder3 = value[1], value[2], value[3]
            file1, file2, file3 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            filepath3 = os.path.join(base_folder, subfolder3, file3)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2, open(filepath3, 'r') as f3:
                content = f1.read() + f2.read() + f3.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        new_dict[new_filename] = value
        id_counter += 1

    return new_dict

# %%
new_files_dict = create_files_and_new_dict(predefined_shuffled_dict, '../TSB-UAD-Public/TSB-UAD-Public')

# %%
for key, value in new_files_dict.items():
    print(f"{key}: {value}")
# Out:
# ts1: ['Normality_1', 'Occupancy']
# ts2: ['Normality_2', 'YAHOO', 'Dodgers']
# ts3: ['Normality_2', 'SVDB', 'SensorScope']
# ts4: ['Normality_2', 'Occupancy', 'Dodgers']
# ts5: ['Normality_1', 'IOPS']
# ts6: ['Normality_3', 'YAHOO', 'SMD', 'SensorScope']
# ts7: ['Normality_2', 'MGAB', 'SensorScope']
# ts8: ['Normality_3', 'NASA-MSL', 'SVDB', 'Occupancy']
# ts9: ['Normality_3', 'KDD21', 'GHL', 'SMD']
# ts10: ['Normality_3', 'YAHOO', 'OPPORTUNITY', 'NAB']
# ts11: ['Normality_1', 'NASA-MSL']
# ts12: ['Normality_3', 'NASA-SMAP', 'Occupancy', 'Dodgers']
# ts13: ['Normality_2', 'SVDB', 'NAB']
# ts14: ['Normality_1', 'IOPS']
# ts15: ['Normality_1', 'OPPORTUNITY']

# %%
new_files_dict = dict(sorted(new_files_dict.items(), key=lambda item: item[1][0]))

# %%
for key, value in new_files_dict.items():
    print(f"{key}: {value}")
# Out:
# ts1: ['Normality_1', 'Occupancy']
# ts5: ['Normality_1', 'IOPS']
# ts11: ['Normality_1', 'NASA-MSL']
# ts14: ['Normality_1', 'IOPS']
# ts15: ['Normality_1', 'OPPORTUNITY']
# ts2: ['Normality_2', 'YAHOO', 'Dodgers']
# ts3: ['Normality_2', 'SVDB', 'SensorScope']
# ts4: ['Normality_2', 'Occupancy', 'Dodgers']
# ts7: ['Normality_2', 'MGAB', 'SensorScope']
# ts13: ['Normality_2', 'SVDB', 'NAB']
# ts6: ['Normality_3', 'YAHOO', 'SMD', 'SensorScope']
# ts8: ['Normality_3', 'NASA-MSL', 'SVDB', 'Occupancy']
# ts9: ['Normality_3', 'KDD21', 'GHL', 'SMD']
# ts10: ['Normality_3', 'YAHOO', 'OPPORTUNITY', 'NAB']
# ts12: ['Normality_3', 'NASA-SMAP', 'Occupancy', 'Dodgers']

# %%
with open('Time-Series-Data-Dictionary.json', 'w') as json_file:
    json.dump(new_files_dict, json_file, indent=4)

# %% [markdown]
# # ***Generated TS Plots***,
# Let's plot the time-series files to get an idea of what files were chosen.

# %%
def plot_time_series_subplots(file_dict, data_folder):
    num_files = len(file_dict)
    fig, axs = plt.subplots(num_files, 1, figsize=(10, num_files * 5))

    if num_files == 1:
        axs = [axs]

    for idx, (filename, info) in enumerate(file_dict.items()):
        file_path = os.path.join(data_folder, filename)
        
        try:
            data = pd.read_csv(file_path)
        except FileNotFoundError:
            print(f"File not found: {file_path}")
            continue
        
        time_series = data.iloc[:, 0]
        
        normality = info[0]
        subfolders = ", ".join(info[1:])
        
        axs[idx].plot(time_series)
        axs[idx].set_title(f"Filename: {filename}\nNormality: {normality}\nSubfolders: {subfolders}")
        axs[idx].set_xlabel('Time')
        axs[idx].set_ylabel('Value')
        axs[idx].grid(True)

    plt.tight_layout()
    plt.show()

# Call the function to plot the data
plot_time_series_subplots(new_files_dict, 'TS-Data-Files')
