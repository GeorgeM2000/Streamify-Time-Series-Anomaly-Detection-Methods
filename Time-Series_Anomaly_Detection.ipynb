# %% [markdown]
# # ***Libraries***

# %%
import os
import random

# %% [markdown]
# # ***File Extraction***

# %%
def count_files_and_organize_by_subfolder(folder_path):
    subfolder_files = {}

    for subdir, _, files in os.walk(folder_path):
        subfolder_name = os.path.basename(subdir)
        if subfolder_name not in subfolder_files:
            subfolder_files[subfolder_name] = []

        subfolder_files[subfolder_name].extend(files)

    return subfolder_files

def print_subfolder_files_info(subfolder_files):
    for subfolder, files in subfolder_files.items():
        print(f"Subfolder: {subfolder}")
        #for file in files:
            #print(f"  File: {file}")
        print(f"Number of files in '{subfolder}': {len(files)}\n")

tsb_uad_pub_folder_path = '../TSB-UAD-Public/TSB-UAD-Public'
subfolder_files = count_files_and_organize_by_subfolder(tsb_uad_pub_folder_path)
del subfolder_files['TSB-UAD-Public']
print_subfolder_files_info(subfolder_files)
# Out:
# Subfolder: MITDB
# Number of files in 'MITDB': 32
#
# Subfolder: NAB
# Number of files in 'NAB': 58
#
# Subfolder: ECG
# Number of files in 'ECG': 53
#
# Subfolder: GHL
# Number of files in 'GHL': 126
#
# Subfolder: NASA-SMAP
# Number of files in 'NASA-SMAP': 108
#
# Subfolder: KDD21
# Number of files in 'KDD21': 250
#
# Subfolder: NASA-MSL
# Number of files in 'NASA-MSL': 54
#
# Subfolder: SensorScope
# Number of files in 'SensorScope': 23
#
# Subfolder: Occupancy
# Number of files in 'Occupancy': 10
#
# Subfolder: Daphnet
# Number of files in 'Daphnet': 45
#
# Subfolder: OPPORTUNITY
# Number of files in 'OPPORTUNITY': 465
#
# Subfolder: SVDB
# Number of files in 'SVDB': 115
#
# Subfolder: SMD
# Number of files in 'SMD': 281
#
# Subfolder: MGAB
# Number of files in 'MGAB': 10
#
# Subfolder: IOPS
# Number of files in 'IOPS': 58
#
# Subfolder: Genesis
# Number of files in 'Genesis': 6
#
# Subfolder: YAHOO
# Number of files in 'YAHOO': 367
#
# Subfolder: Dodgers
# Number of files in 'Dodgers': 1

# %%
def create_normality_dicts(subfolder_files):
    # Create Normality_1
    normality_1 = {}
    for subfolder, files in subfolder_files.items():
        if files:
            num_files_to_take = min(random.randint(1, 3), len(files))
            normality_1[subfolder] = random.sample(files, num_files_to_take)
    
    # Create Normality_2
    normality_2 = {}
    subfolder_list = list(normality_1.keys())
    for i in range(len(subfolder_list)):
        for j in range(i + 1, len(subfolder_list)):
            subfolder_a = subfolder_list[i]
            subfolder_b = subfolder_list[j]
            files_a = normality_1[subfolder_a]
            files_b = normality_1[subfolder_b]
            if files_a and files_b:
                file_a = random.choice(files_a)
                file_b = random.choice(files_b)
                key = f"{file_a}+{file_b}"
                normality_2[key] = (subfolder_a, subfolder_b)
    
    # Create Normality_3
    normality_3 = {}
    for i in range(len(subfolder_list)):
        for j in range(i + 1, len(subfolder_list)):
            for k in range(j + 1, len(subfolder_list)):
                subfolder_a = subfolder_list[i]
                subfolder_b = subfolder_list[j]
                subfolder_c = subfolder_list[k]
                files_a = normality_1[subfolder_a]
                files_b = normality_1[subfolder_b]
                files_c = normality_1[subfolder_c]
                if files_a and files_b and files_c:
                    file_a = random.choice(files_a)
                    file_b = random.choice(files_b)
                    file_c = random.choice(files_c)
                    key = f"{file_a}+{file_b}+{file_c}"
                    normality_3[key] = (subfolder_a, subfolder_b, subfolder_c)

    return normality_1, normality_2, normality_3

# %%
normality_1, normality_2, normality_3 = create_normality_dicts(subfolder_files)

# %%
# Print the dictionaries
print("Normality_1:")
for subfolder, files in normality_1.items():
    print(f"{subfolder}: {files}")

print("\nNormality_2:")
for key, value in normality_2.items():
    print(f"{key}: {value}")

print("\nNormality_3:")
for key, value in normality_3.items():
    print(f"{key}: {value}")
# Out:
# Normality_1:
# MITDB: ['221.test.csv@2.out', '122.test.csv@1.out', '221.test.csv@1.out']
# NAB: ['NAB_data_Traffic_5.out', 'NAB_data_Exchange_2.out']
# ECG: ['MBA_ECG14046_data_11.out', 'MBA_ECG14046_data_37.out', 'MBA_ECG14046_data_12.out']
# GHL: ['15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out']
# NASA-SMAP: ['D-13.train.out', 'D-8.test.out', 'A-8.train.out']
# KDD21: ['080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out', '039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out', '073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out']
# NASA-MSL: ['M-3.train.out', 'M-6.test.out']
# SensorScope: ['stb-7.test.out', 'stb-3.test.out']
# Occupancy: ['room-occupancy-0.test.csv@3.out']
# Daphnet: ['S03R01E0.test.csv@8.out', 'S03R01E1.test.csv@2.out', 'S09R01E0.test.csv@1.out']
# OPPORTUNITY: ['S2-ADL5.test.csv@81.out', 'S4-ADL4.test.csv@108.out']
# SVDB: ['870.test.csv@2.out', '806.test.csv@1.out']
# SMD: ['machine-1-1.test.csv@19.out', 'machine-3-5.test.csv@31.out', 'machine-2-8.test.csv@32.out']
# MGAB: ['9.test.out', '3.test.out']
# IOPS: ['KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out', 'KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out', 'KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out']
# Genesis: ['genesis-anomalies.test.csv@5.out', 'genesis-anomalies.test.csv@6.out', 'genesis-anomalies.test.csv@13.out']
# YAHOO: ['YahooA3Benchmark-TS29_data.out']
# Dodgers: ['101-freeway-traffic.test.out']
#
# Normality_2:
# 122.test.csv@1.out+NAB_data_Exchange_2.out: ('MITDB', 'NAB')
# 221.test.csv@1.out+MBA_ECG14046_data_12.out: ('MITDB', 'ECG')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('MITDB', 'GHL')
# 122.test.csv@1.out+D-8.test.out: ('MITDB', 'NASA-SMAP')
# 221.test.csv@2.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out: ('MITDB', 'KDD21')
# 122.test.csv@1.out+M-6.test.out: ('MITDB', 'NASA-MSL')
# 221.test.csv@2.out+stb-3.test.out: ('MITDB', 'SensorScope')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'Occupancy')
# 122.test.csv@1.out+S03R01E0.test.csv@8.out: ('MITDB', 'Daphnet')
# 221.test.csv@2.out+S2-ADL5.test.csv@81.out: ('MITDB', 'OPPORTUNITY')
# 122.test.csv@1.out+806.test.csv@1.out: ('MITDB', 'SVDB')
# 122.test.csv@1.out+machine-3-5.test.csv@31.out: ('MITDB', 'SMD')
# 221.test.csv@1.out+9.test.out: ('MITDB', 'MGAB')
# 221.test.csv@2.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('MITDB', 'IOPS')
# 122.test.csv@1.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'Genesis')
# 122.test.csv@1.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'YAHOO')
# 221.test.csv@2.out+101-freeway-traffic.test.out: ('MITDB', 'Dodgers')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_12.out: ('NAB', 'ECG')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('NAB', 'GHL')
# NAB_data_Exchange_2.out+D-13.train.out: ('NAB', 'NASA-SMAP')
# NAB_data_Traffic_5.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('NAB', 'KDD21')
# NAB_data_Exchange_2.out+M-3.train.out: ('NAB', 'NASA-MSL')
# NAB_data_Exchange_2.out+stb-3.test.out: ('NAB', 'SensorScope')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out: ('NAB', 'Occupancy')
# NAB_data_Exchange_2.out+S03R01E1.test.csv@2.out: ('NAB', 'Daphnet')
# NAB_data_Exchange_2.out+S4-ADL4.test.csv@108.out: ('NAB', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+806.test.csv@1.out: ('NAB', 'SVDB')
# NAB_data_Exchange_2.out+machine-3-5.test.csv@31.out: ('NAB', 'SMD')
# NAB_data_Traffic_5.out+9.test.out: ('NAB', 'MGAB')
# NAB_data_Traffic_5.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('NAB', 'IOPS')
# NAB_data_Traffic_5.out+genesis-anomalies.test.csv@13.out: ('NAB', 'Genesis')
# NAB_data_Traffic_5.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'YAHOO')
# NAB_data_Exchange_2.out+101-freeway-traffic.test.out: ('NAB', 'Dodgers')
# MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('ECG', 'GHL')
# MBA_ECG14046_data_11.out+D-13.train.out: ('ECG', 'NASA-SMAP')
# MBA_ECG14046_data_12.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out: ('ECG', 'KDD21')
# MBA_ECG14046_data_11.out+M-3.train.out: ('ECG', 'NASA-MSL')
# MBA_ECG14046_data_12.out+stb-3.test.out: ('ECG', 'SensorScope')
# MBA_ECG14046_data_11.out+room-occupancy-0.test.csv@3.out: ('ECG', 'Occupancy')
# MBA_ECG14046_data_11.out+S03R01E0.test.csv@8.out: ('ECG', 'Daphnet')
# MBA_ECG14046_data_11.out+S2-ADL5.test.csv@81.out: ('ECG', 'OPPORTUNITY')
# MBA_ECG14046_data_37.out+806.test.csv@1.out: ('ECG', 'SVDB')
# MBA_ECG14046_data_11.out+machine-2-8.test.csv@32.out: ('ECG', 'SMD')
# MBA_ECG14046_data_11.out+3.test.out: ('ECG', 'MGAB')
# MBA_ECG14046_data_11.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('ECG', 'IOPS')
# MBA_ECG14046_data_11.out+genesis-anomalies.test.csv@5.out: ('ECG', 'Genesis')
# MBA_ECG14046_data_11.out+YahooA3Benchmark-TS29_data.out: ('ECG', 'YAHOO')
# MBA_ECG14046_data_37.out+101-freeway-traffic.test.out: ('ECG', 'Dodgers')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+D-8.test.out: ('GHL', 'NASA-SMAP')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out: ('GHL', 'KDD21')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+M-3.train.out: ('GHL', 'NASA-MSL')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-3.test.out: ('GHL', 'SensorScope')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('GHL', 'Occupancy')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S03R01E0.test.csv@8.out: ('GHL', 'Daphnet')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S4-ADL4.test.csv@108.out: ('GHL', 'OPPORTUNITY')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+870.test.csv@2.out: ('GHL', 'SVDB')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+machine-3-5.test.csv@31.out: ('GHL', 'SMD')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+9.test.out: ('GHL', 'MGAB')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('GHL', 'IOPS')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+genesis-anomalies.test.csv@13.out: ('GHL', 'Genesis')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('GHL', 'YAHOO')
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('GHL', 'Dodgers')
# D-13.train.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('NASA-SMAP', 'KDD21')
# A-8.train.out+M-3.train.out: ('NASA-SMAP', 'NASA-MSL')
# A-8.train.out+stb-7.test.out: ('NASA-SMAP', 'SensorScope')
# D-8.test.out+room-occupancy-0.test.csv@3.out: ('NASA-SMAP', 'Occupancy')
# D-13.train.out+S09R01E0.test.csv@1.out: ('NASA-SMAP', 'Daphnet')
# D-8.test.out+S4-ADL4.test.csv@108.out: ('NASA-SMAP', 'OPPORTUNITY')
# A-8.train.out+870.test.csv@2.out: ('NASA-SMAP', 'SVDB')
# D-8.test.out+machine-1-1.test.csv@19.out: ('NASA-SMAP', 'SMD')
# A-8.train.out+9.test.out: ('NASA-SMAP', 'MGAB')
# D-8.test.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('NASA-SMAP', 'IOPS')
# D-13.train.out+genesis-anomalies.test.csv@6.out: ('NASA-SMAP', 'Genesis')
# D-8.test.out+YahooA3Benchmark-TS29_data.out: ('NASA-SMAP', 'YAHOO')
# D-13.train.out+101-freeway-traffic.test.out: ('NASA-SMAP', 'Dodgers')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+M-6.test.out: ('KDD21', 'NASA-MSL')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+stb-3.test.out: ('KDD21', 'SensorScope')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+room-occupancy-0.test.csv@3.out: ('KDD21', 'Occupancy')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+S09R01E0.test.csv@1.out: ('KDD21', 'Daphnet')
# 073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+S4-ADL4.test.csv@108.out: ('KDD21', 'OPPORTUNITY')
# 073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+870.test.csv@2.out: ('KDD21', 'SVDB')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+machine-1-1.test.csv@19.out: ('KDD21', 'SMD')
# 080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+9.test.out: ('KDD21', 'MGAB')
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('KDD21', 'IOPS')
# 073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+genesis-anomalies.test.csv@6.out: ('KDD21', 'Genesis')
# 080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+YahooA3Benchmark-TS29_data.out: ('KDD21', 'YAHOO')
# 073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+101-freeway-traffic.test.out: ('KDD21', 'Dodgers')
# M-3.train.out+stb-3.test.out: ('NASA-MSL', 'SensorScope')
# M-3.train.out+room-occupancy-0.test.csv@3.out: ('NASA-MSL', 'Occupancy')
# M-6.test.out+S03R01E0.test.csv@8.out: ('NASA-MSL', 'Daphnet')
# M-6.test.out+S4-ADL4.test.csv@108.out: ('NASA-MSL', 'OPPORTUNITY')
# M-6.test.out+870.test.csv@2.out: ('NASA-MSL', 'SVDB')
# M-6.test.out+machine-2-8.test.csv@32.out: ('NASA-MSL', 'SMD')
# M-3.train.out+9.test.out: ('NASA-MSL', 'MGAB')
# M-3.train.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NASA-MSL', 'IOPS')
# M-6.test.out+genesis-anomalies.test.csv@13.out: ('NASA-MSL', 'Genesis')
# M-3.train.out+YahooA3Benchmark-TS29_data.out: ('NASA-MSL', 'YAHOO')
# M-3.train.out+101-freeway-traffic.test.out: ('NASA-MSL', 'Dodgers')
# stb-7.test.out+room-occupancy-0.test.csv@3.out: ('SensorScope', 'Occupancy')
# stb-3.test.out+S03R01E0.test.csv@8.out: ('SensorScope', 'Daphnet')
# stb-7.test.out+S2-ADL5.test.csv@81.out: ('SensorScope', 'OPPORTUNITY')
# stb-3.test.out+806.test.csv@1.out: ('SensorScope', 'SVDB')
# stb-3.test.out+machine-1-1.test.csv@19.out: ('SensorScope', 'SMD')
# stb-3.test.out+9.test.out: ('SensorScope', 'MGAB')
# stb-7.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('SensorScope', 'IOPS')
# stb-7.test.out+genesis-anomalies.test.csv@5.out: ('SensorScope', 'Genesis')
# stb-7.test.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'YAHOO')
# stb-3.test.out+101-freeway-traffic.test.out: ('SensorScope', 'Dodgers')
# room-occupancy-0.test.csv@3.out+S03R01E0.test.csv@8.out: ('Occupancy', 'Daphnet')
# room-occupancy-0.test.csv@3.out+S4-ADL4.test.csv@108.out: ('Occupancy', 'OPPORTUNITY')
# room-occupancy-0.test.csv@3.out+806.test.csv@1.out: ('Occupancy', 'SVDB')
# room-occupancy-0.test.csv@3.out+machine-3-5.test.csv@31.out: ('Occupancy', 'SMD')
# room-occupancy-0.test.csv@3.out+9.test.out: ('Occupancy', 'MGAB')
# room-occupancy-0.test.csv@3.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Occupancy', 'IOPS')
# room-occupancy-0.test.csv@3.out+genesis-anomalies.test.csv@6.out: ('Occupancy', 'Genesis')
# room-occupancy-0.test.csv@3.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'YAHOO')
# room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('Occupancy', 'Dodgers')
# S03R01E1.test.csv@2.out+S4-ADL4.test.csv@108.out: ('Daphnet', 'OPPORTUNITY')
# S03R01E0.test.csv@8.out+870.test.csv@2.out: ('Daphnet', 'SVDB')
# S03R01E0.test.csv@8.out+machine-1-1.test.csv@19.out: ('Daphnet', 'SMD')
# S09R01E0.test.csv@1.out+3.test.out: ('Daphnet', 'MGAB')
# S03R01E1.test.csv@2.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('Daphnet', 'IOPS')
# S03R01E0.test.csv@8.out+genesis-anomalies.test.csv@13.out: ('Daphnet', 'Genesis')
# S09R01E0.test.csv@1.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'YAHOO')
# S09R01E0.test.csv@1.out+101-freeway-traffic.test.out: ('Daphnet', 'Dodgers')
# S4-ADL4.test.csv@108.out+870.test.csv@2.out: ('OPPORTUNITY', 'SVDB')
# S2-ADL5.test.csv@81.out+machine-2-8.test.csv@32.out: ('OPPORTUNITY', 'SMD')
# S4-ADL4.test.csv@108.out+9.test.out: ('OPPORTUNITY', 'MGAB')
# S4-ADL4.test.csv@108.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('OPPORTUNITY', 'IOPS')
# S2-ADL5.test.csv@81.out+genesis-anomalies.test.csv@6.out: ('OPPORTUNITY', 'Genesis')
# S2-ADL5.test.csv@81.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'YAHOO')
# S4-ADL4.test.csv@108.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'Dodgers')
# 870.test.csv@2.out+machine-3-5.test.csv@31.out: ('SVDB', 'SMD')
# 806.test.csv@1.out+3.test.out: ('SVDB', 'MGAB')
# 806.test.csv@1.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('SVDB', 'IOPS')
# 870.test.csv@2.out+genesis-anomalies.test.csv@5.out: ('SVDB', 'Genesis')
# 806.test.csv@1.out+YahooA3Benchmark-TS29_data.out: ('SVDB', 'YAHOO')
# 806.test.csv@1.out+101-freeway-traffic.test.out: ('SVDB', 'Dodgers')
# machine-3-5.test.csv@31.out+3.test.out: ('SMD', 'MGAB')
# machine-2-8.test.csv@32.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('SMD', 'IOPS')
# machine-3-5.test.csv@31.out+genesis-anomalies.test.csv@5.out: ('SMD', 'Genesis')
# machine-1-1.test.csv@19.out+YahooA3Benchmark-TS29_data.out: ('SMD', 'YAHOO')
# machine-1-1.test.csv@19.out+101-freeway-traffic.test.out: ('SMD', 'Dodgers')
# 9.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MGAB', 'IOPS')
# 3.test.out+genesis-anomalies.test.csv@5.out: ('MGAB', 'Genesis')
# 3.test.out+YahooA3Benchmark-TS29_data.out: ('MGAB', 'YAHOO')
# 9.test.out+101-freeway-traffic.test.out: ('MGAB', 'Dodgers')
# KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+genesis-anomalies.test.csv@6.out: ('IOPS', 'Genesis')
# KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+YahooA3Benchmark-TS29_data.out: ('IOPS', 'YAHOO')
# KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ('IOPS', 'Dodgers')
# genesis-anomalies.test.csv@5.out+YahooA3Benchmark-TS29_data.out: ('Genesis', 'YAHOO')
# genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('Genesis', 'Dodgers')
# YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('YAHOO', 'Dodgers')
#
# Normality_3:
# 221.test.csv@2.out+NAB_data_Exchange_2.out+MBA_ECG14046_data_11.out: ('MITDB', 'NAB', 'ECG')
# 221.test.csv@2.out+NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('MITDB', 'NAB', 'GHL')
# 221.test.csv@2.out+NAB_data_Traffic_5.out+D-13.train.out: ('MITDB', 'NAB', 'NASA-SMAP')
# 221.test.csv@1.out+NAB_data_Traffic_5.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out: ('MITDB', 'NAB', 'KDD21')
# 221.test.csv@2.out+NAB_data_Traffic_5.out+M-6.test.out: ('MITDB', 'NAB', 'NASA-MSL')
# 221.test.csv@1.out+NAB_data_Traffic_5.out+stb-7.test.out: ('MITDB', 'NAB', 'SensorScope')
# 122.test.csv@1.out+NAB_data_Traffic_5.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'NAB', 'Occupancy')
# 221.test.csv@2.out+NAB_data_Traffic_5.out+S03R01E1.test.csv@2.out: ('MITDB', 'NAB', 'Daphnet')
# 122.test.csv@1.out+NAB_data_Exchange_2.out+S4-ADL4.test.csv@108.out: ('MITDB', 'NAB', 'OPPORTUNITY')
# 122.test.csv@1.out+NAB_data_Exchange_2.out+870.test.csv@2.out: ('MITDB', 'NAB', 'SVDB')
# 221.test.csv@2.out+NAB_data_Exchange_2.out+machine-3-5.test.csv@31.out: ('MITDB', 'NAB', 'SMD')
# 221.test.csv@2.out+NAB_data_Exchange_2.out+3.test.out: ('MITDB', 'NAB', 'MGAB')
# 221.test.csv@2.out+NAB_data_Traffic_5.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('MITDB', 'NAB', 'IOPS')
# 122.test.csv@1.out+NAB_data_Exchange_2.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'NAB', 'Genesis')
# 122.test.csv@1.out+NAB_data_Exchange_2.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'NAB', 'YAHOO')
# 122.test.csv@1.out+NAB_data_Exchange_2.out+101-freeway-traffic.test.out: ('MITDB', 'NAB', 'Dodgers')
# 221.test.csv@1.out+MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('MITDB', 'ECG', 'GHL')
# 221.test.csv@1.out+MBA_ECG14046_data_12.out+A-8.train.out: ('MITDB', 'ECG', 'NASA-SMAP')
# 221.test.csv@2.out+MBA_ECG14046_data_12.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('MITDB', 'ECG', 'KDD21')
# 221.test.csv@2.out+MBA_ECG14046_data_11.out+M-3.train.out: ('MITDB', 'ECG', 'NASA-MSL')
# 122.test.csv@1.out+MBA_ECG14046_data_37.out+stb-7.test.out: ('MITDB', 'ECG', 'SensorScope')
# 221.test.csv@2.out+MBA_ECG14046_data_11.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'ECG', 'Occupancy')
# 122.test.csv@1.out+MBA_ECG14046_data_11.out+S03R01E1.test.csv@2.out: ('MITDB', 'ECG', 'Daphnet')
# 221.test.csv@2.out+MBA_ECG14046_data_11.out+S2-ADL5.test.csv@81.out: ('MITDB', 'ECG', 'OPPORTUNITY')
# 221.test.csv@2.out+MBA_ECG14046_data_11.out+870.test.csv@2.out: ('MITDB', 'ECG', 'SVDB')
# 122.test.csv@1.out+MBA_ECG14046_data_12.out+machine-1-1.test.csv@19.out: ('MITDB', 'ECG', 'SMD')
# 122.test.csv@1.out+MBA_ECG14046_data_37.out+3.test.out: ('MITDB', 'ECG', 'MGAB')
# 122.test.csv@1.out+MBA_ECG14046_data_37.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'ECG', 'IOPS')
# 221.test.csv@1.out+MBA_ECG14046_data_11.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'ECG', 'Genesis')
# 221.test.csv@2.out+MBA_ECG14046_data_11.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'ECG', 'YAHOO')
# 221.test.csv@2.out+MBA_ECG14046_data_37.out+101-freeway-traffic.test.out: ('MITDB', 'ECG', 'Dodgers')
# 122.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+D-13.train.out: ('MITDB', 'GHL', 'NASA-SMAP')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out: ('MITDB', 'GHL', 'KDD21')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+M-6.test.out: ('MITDB', 'GHL', 'NASA-MSL')
# 122.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-3.test.out: ('MITDB', 'GHL', 'SensorScope')
# 122.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'GHL', 'Occupancy')
# 122.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S03R01E1.test.csv@2.out: ('MITDB', 'GHL', 'Daphnet')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S2-ADL5.test.csv@81.out: ('MITDB', 'GHL', 'OPPORTUNITY')
# 221.test.csv@2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+870.test.csv@2.out: ('MITDB', 'GHL', 'SVDB')
# 122.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+machine-1-1.test.csv@19.out: ('MITDB', 'GHL', 'SMD')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+3.test.out: ('MITDB', 'GHL', 'MGAB')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('MITDB', 'GHL', 'IOPS')
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'GHL', 'Genesis')
# 221.test.csv@2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'GHL', 'YAHOO')
# 221.test.csv@2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('MITDB', 'GHL', 'Dodgers')
# 221.test.csv@1.out+D-8.test.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('MITDB', 'NASA-SMAP', 'KDD21')
# 122.test.csv@1.out+D-13.train.out+M-3.train.out: ('MITDB', 'NASA-SMAP', 'NASA-MSL')
# 221.test.csv@1.out+A-8.train.out+stb-7.test.out: ('MITDB', 'NASA-SMAP', 'SensorScope')
# 221.test.csv@1.out+A-8.train.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'NASA-SMAP', 'Occupancy')
# 221.test.csv@2.out+D-13.train.out+S03R01E1.test.csv@2.out: ('MITDB', 'NASA-SMAP', 'Daphnet')
# 221.test.csv@2.out+D-13.train.out+S4-ADL4.test.csv@108.out: ('MITDB', 'NASA-SMAP', 'OPPORTUNITY')
# 221.test.csv@2.out+D-8.test.out+870.test.csv@2.out: ('MITDB', 'NASA-SMAP', 'SVDB')
# 221.test.csv@2.out+D-13.train.out+machine-3-5.test.csv@31.out: ('MITDB', 'NASA-SMAP', 'SMD')
# 221.test.csv@1.out+D-13.train.out+3.test.out: ('MITDB', 'NASA-SMAP', 'MGAB')
# 122.test.csv@1.out+A-8.train.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('MITDB', 'NASA-SMAP', 'IOPS')
# 221.test.csv@2.out+A-8.train.out+genesis-anomalies.test.csv@5.out: ('MITDB', 'NASA-SMAP', 'Genesis')
# 221.test.csv@1.out+A-8.train.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'NASA-SMAP', 'YAHOO')
# 122.test.csv@1.out+D-13.train.out+101-freeway-traffic.test.out: ('MITDB', 'NASA-SMAP', 'Dodgers')
# 221.test.csv@1.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+M-6.test.out: ('MITDB', 'KDD21', 'NASA-MSL')
# 122.test.csv@1.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+stb-3.test.out: ('MITDB', 'KDD21', 'SensorScope')
# 122.test.csv@1.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'KDD21', 'Occupancy')
# 221.test.csv@2.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+S03R01E0.test.csv@8.out: ('MITDB', 'KDD21', 'Daphnet')
# 122.test.csv@1.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+S2-ADL5.test.csv@81.out: ('MITDB', 'KDD21', 'OPPORTUNITY')
# 221.test.csv@2.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+806.test.csv@1.out: ('MITDB', 'KDD21', 'SVDB')
# 221.test.csv@2.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+machine-1-1.test.csv@19.out: ('MITDB', 'KDD21', 'SMD')
# 221.test.csv@2.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+9.test.out: ('MITDB', 'KDD21', 'MGAB')
# 122.test.csv@1.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'KDD21', 'IOPS')
# 221.test.csv@2.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'KDD21', 'Genesis')
# 221.test.csv@2.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'KDD21', 'YAHOO')
# 221.test.csv@2.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+101-freeway-traffic.test.out: ('MITDB', 'KDD21', 'Dodgers')
# 221.test.csv@2.out+M-3.train.out+stb-3.test.out: ('MITDB', 'NASA-MSL', 'SensorScope')
# 221.test.csv@1.out+M-3.train.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'NASA-MSL', 'Occupancy')
# 122.test.csv@1.out+M-3.train.out+S03R01E0.test.csv@8.out: ('MITDB', 'NASA-MSL', 'Daphnet')
# 221.test.csv@1.out+M-3.train.out+S4-ADL4.test.csv@108.out: ('MITDB', 'NASA-MSL', 'OPPORTUNITY')
# 122.test.csv@1.out+M-6.test.out+870.test.csv@2.out: ('MITDB', 'NASA-MSL', 'SVDB')
# 221.test.csv@2.out+M-3.train.out+machine-1-1.test.csv@19.out: ('MITDB', 'NASA-MSL', 'SMD')
# 221.test.csv@1.out+M-3.train.out+3.test.out: ('MITDB', 'NASA-MSL', 'MGAB')
# 122.test.csv@1.out+M-3.train.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('MITDB', 'NASA-MSL', 'IOPS')
# 221.test.csv@1.out+M-6.test.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'NASA-MSL', 'Genesis')
# 221.test.csv@1.out+M-6.test.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'NASA-MSL', 'YAHOO')
# 221.test.csv@1.out+M-6.test.out+101-freeway-traffic.test.out: ('MITDB', 'NASA-MSL', 'Dodgers')
# 221.test.csv@2.out+stb-3.test.out+room-occupancy-0.test.csv@3.out: ('MITDB', 'SensorScope', 'Occupancy')
# 122.test.csv@1.out+stb-7.test.out+S03R01E1.test.csv@2.out: ('MITDB', 'SensorScope', 'Daphnet')
# 221.test.csv@2.out+stb-7.test.out+S2-ADL5.test.csv@81.out: ('MITDB', 'SensorScope', 'OPPORTUNITY')
# 221.test.csv@2.out+stb-3.test.out+806.test.csv@1.out: ('MITDB', 'SensorScope', 'SVDB')
# 122.test.csv@1.out+stb-7.test.out+machine-1-1.test.csv@19.out: ('MITDB', 'SensorScope', 'SMD')
# 221.test.csv@1.out+stb-7.test.out+3.test.out: ('MITDB', 'SensorScope', 'MGAB')
# 122.test.csv@1.out+stb-7.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'SensorScope', 'IOPS')
# 221.test.csv@1.out+stb-3.test.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'SensorScope', 'Genesis')
# 221.test.csv@2.out+stb-3.test.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'SensorScope', 'YAHOO')
# 221.test.csv@2.out+stb-7.test.out+101-freeway-traffic.test.out: ('MITDB', 'SensorScope', 'Dodgers')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+S09R01E0.test.csv@1.out: ('MITDB', 'Occupancy', 'Daphnet')
# 221.test.csv@1.out+room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out: ('MITDB', 'Occupancy', 'OPPORTUNITY')
# 221.test.csv@1.out+room-occupancy-0.test.csv@3.out+806.test.csv@1.out: ('MITDB', 'Occupancy', 'SVDB')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+machine-2-8.test.csv@32.out: ('MITDB', 'Occupancy', 'SMD')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+9.test.out: ('MITDB', 'Occupancy', 'MGAB')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('MITDB', 'Occupancy', 'IOPS')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'Occupancy', 'Genesis')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'Occupancy', 'YAHOO')
# 221.test.csv@2.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('MITDB', 'Occupancy', 'Dodgers')
# 221.test.csv@1.out+S03R01E0.test.csv@8.out+S4-ADL4.test.csv@108.out: ('MITDB', 'Daphnet', 'OPPORTUNITY')
# 221.test.csv@2.out+S03R01E0.test.csv@8.out+806.test.csv@1.out: ('MITDB', 'Daphnet', 'SVDB')
# 221.test.csv@1.out+S03R01E0.test.csv@8.out+machine-2-8.test.csv@32.out: ('MITDB', 'Daphnet', 'SMD')
# 221.test.csv@2.out+S03R01E0.test.csv@8.out+9.test.out: ('MITDB', 'Daphnet', 'MGAB')
# 221.test.csv@1.out+S03R01E1.test.csv@2.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'Daphnet', 'IOPS')
# 221.test.csv@1.out+S03R01E0.test.csv@8.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'Daphnet', 'Genesis')
# 221.test.csv@2.out+S03R01E1.test.csv@2.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'Daphnet', 'YAHOO')
# 122.test.csv@1.out+S03R01E0.test.csv@8.out+101-freeway-traffic.test.out: ('MITDB', 'Daphnet', 'Dodgers')
# 122.test.csv@1.out+S2-ADL5.test.csv@81.out+806.test.csv@1.out: ('MITDB', 'OPPORTUNITY', 'SVDB')
# 221.test.csv@1.out+S4-ADL4.test.csv@108.out+machine-1-1.test.csv@19.out: ('MITDB', 'OPPORTUNITY', 'SMD')
# 122.test.csv@1.out+S4-ADL4.test.csv@108.out+3.test.out: ('MITDB', 'OPPORTUNITY', 'MGAB')
# 122.test.csv@1.out+S2-ADL5.test.csv@81.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'OPPORTUNITY', 'IOPS')
# 221.test.csv@1.out+S4-ADL4.test.csv@108.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'OPPORTUNITY', 'Genesis')
# 122.test.csv@1.out+S4-ADL4.test.csv@108.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'OPPORTUNITY', 'YAHOO')
# 221.test.csv@2.out+S4-ADL4.test.csv@108.out+101-freeway-traffic.test.out: ('MITDB', 'OPPORTUNITY', 'Dodgers')
# 221.test.csv@1.out+870.test.csv@2.out+machine-1-1.test.csv@19.out: ('MITDB', 'SVDB', 'SMD')
# 122.test.csv@1.out+806.test.csv@1.out+3.test.out: ('MITDB', 'SVDB', 'MGAB')
# 221.test.csv@2.out+806.test.csv@1.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'SVDB', 'IOPS')
# 221.test.csv@2.out+870.test.csv@2.out+genesis-anomalies.test.csv@5.out: ('MITDB', 'SVDB', 'Genesis')
# 221.test.csv@1.out+806.test.csv@1.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'SVDB', 'YAHOO')
# 221.test.csv@1.out+870.test.csv@2.out+101-freeway-traffic.test.out: ('MITDB', 'SVDB', 'Dodgers')
# 221.test.csv@1.out+machine-3-5.test.csv@31.out+3.test.out: ('MITDB', 'SMD', 'MGAB')
# 221.test.csv@2.out+machine-2-8.test.csv@32.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'SMD', 'IOPS')
# 122.test.csv@1.out+machine-3-5.test.csv@31.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'SMD', 'Genesis')
# 221.test.csv@2.out+machine-2-8.test.csv@32.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'SMD', 'YAHOO')
# 122.test.csv@1.out+machine-3-5.test.csv@31.out+101-freeway-traffic.test.out: ('MITDB', 'SMD', 'Dodgers')
# 221.test.csv@2.out+3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('MITDB', 'MGAB', 'IOPS')
# 221.test.csv@2.out+3.test.out+genesis-anomalies.test.csv@6.out: ('MITDB', 'MGAB', 'Genesis')
# 122.test.csv@1.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'MGAB', 'YAHOO')
# 221.test.csv@1.out+9.test.out+101-freeway-traffic.test.out: ('MITDB', 'MGAB', 'Dodgers')
# 122.test.csv@1.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+genesis-anomalies.test.csv@13.out: ('MITDB', 'IOPS', 'Genesis')
# 122.test.csv@1.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'IOPS', 'YAHOO')
# 221.test.csv@2.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+101-freeway-traffic.test.out: ('MITDB', 'IOPS', 'Dodgers')
# 221.test.csv@1.out+genesis-anomalies.test.csv@13.out+YahooA3Benchmark-TS29_data.out: ('MITDB', 'Genesis', 'YAHOO')
# 122.test.csv@1.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('MITDB', 'Genesis', 'Dodgers')
# 221.test.csv@1.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('MITDB', 'YAHOO', 'Dodgers')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ('NAB', 'ECG', 'GHL')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_37.out+A-8.train.out: ('NAB', 'ECG', 'NASA-SMAP')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_12.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out: ('NAB', 'ECG', 'KDD21')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_37.out+M-6.test.out: ('NAB', 'ECG', 'NASA-MSL')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_12.out+stb-3.test.out: ('NAB', 'ECG', 'SensorScope')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_12.out+room-occupancy-0.test.csv@3.out: ('NAB', 'ECG', 'Occupancy')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_12.out+S03R01E0.test.csv@8.out: ('NAB', 'ECG', 'Daphnet')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_37.out+S2-ADL5.test.csv@81.out: ('NAB', 'ECG', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_11.out+870.test.csv@2.out: ('NAB', 'ECG', 'SVDB')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_11.out+machine-1-1.test.csv@19.out: ('NAB', 'ECG', 'SMD')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_37.out+3.test.out: ('NAB', 'ECG', 'MGAB')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_11.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NAB', 'ECG', 'IOPS')
# NAB_data_Traffic_5.out+MBA_ECG14046_data_11.out+genesis-anomalies.test.csv@5.out: ('NAB', 'ECG', 'Genesis')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_37.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'ECG', 'YAHOO')
# NAB_data_Exchange_2.out+MBA_ECG14046_data_12.out+101-freeway-traffic.test.out: ('NAB', 'ECG', 'Dodgers')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+D-13.train.out: ('NAB', 'GHL', 'NASA-SMAP')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('NAB', 'GHL', 'KDD21')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+M-3.train.out: ('NAB', 'GHL', 'NASA-MSL')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-7.test.out: ('NAB', 'GHL', 'SensorScope')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('NAB', 'GHL', 'Occupancy')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S09R01E0.test.csv@1.out: ('NAB', 'GHL', 'Daphnet')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S2-ADL5.test.csv@81.out: ('NAB', 'GHL', 'OPPORTUNITY')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+870.test.csv@2.out: ('NAB', 'GHL', 'SVDB')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+machine-1-1.test.csv@19.out: ('NAB', 'GHL', 'SMD')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+9.test.out: ('NAB', 'GHL', 'MGAB')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NAB', 'GHL', 'IOPS')
# NAB_data_Exchange_2.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+genesis-anomalies.test.csv@5.out: ('NAB', 'GHL', 'Genesis')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'GHL', 'YAHOO')
# NAB_data_Traffic_5.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('NAB', 'GHL', 'Dodgers')
# NAB_data_Traffic_5.out+D-13.train.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out: ('NAB', 'NASA-SMAP', 'KDD21')
# NAB_data_Traffic_5.out+D-8.test.out+M-3.train.out: ('NAB', 'NASA-SMAP', 'NASA-MSL')
# NAB_data_Exchange_2.out+A-8.train.out+stb-7.test.out: ('NAB', 'NASA-SMAP', 'SensorScope')
# NAB_data_Traffic_5.out+A-8.train.out+room-occupancy-0.test.csv@3.out: ('NAB', 'NASA-SMAP', 'Occupancy')
# NAB_data_Traffic_5.out+A-8.train.out+S03R01E1.test.csv@2.out: ('NAB', 'NASA-SMAP', 'Daphnet')
# NAB_data_Exchange_2.out+D-13.train.out+S2-ADL5.test.csv@81.out: ('NAB', 'NASA-SMAP', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+D-8.test.out+870.test.csv@2.out: ('NAB', 'NASA-SMAP', 'SVDB')
# NAB_data_Exchange_2.out+D-13.train.out+machine-3-5.test.csv@31.out: ('NAB', 'NASA-SMAP', 'SMD')
# NAB_data_Traffic_5.out+D-13.train.out+3.test.out: ('NAB', 'NASA-SMAP', 'MGAB')
# NAB_data_Traffic_5.out+D-8.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('NAB', 'NASA-SMAP', 'IOPS')
# NAB_data_Traffic_5.out+A-8.train.out+genesis-anomalies.test.csv@5.out: ('NAB', 'NASA-SMAP', 'Genesis')
# NAB_data_Exchange_2.out+A-8.train.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'NASA-SMAP', 'YAHOO')
# NAB_data_Exchange_2.out+A-8.train.out+101-freeway-traffic.test.out: ('NAB', 'NASA-SMAP', 'Dodgers')
# NAB_data_Exchange_2.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+M-3.train.out: ('NAB', 'KDD21', 'NASA-MSL')
# NAB_data_Exchange_2.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+stb-3.test.out: ('NAB', 'KDD21', 'SensorScope')
# NAB_data_Traffic_5.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+room-occupancy-0.test.csv@3.out: ('NAB', 'KDD21', 'Occupancy')
# NAB_data_Traffic_5.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+S03R01E0.test.csv@8.out: ('NAB', 'KDD21', 'Daphnet')
# NAB_data_Exchange_2.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+S4-ADL4.test.csv@108.out: ('NAB', 'KDD21', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+806.test.csv@1.out: ('NAB', 'KDD21', 'SVDB')
# NAB_data_Exchange_2.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+machine-3-5.test.csv@31.out: ('NAB', 'KDD21', 'SMD')
# NAB_data_Exchange_2.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+3.test.out: ('NAB', 'KDD21', 'MGAB')
# NAB_data_Exchange_2.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('NAB', 'KDD21', 'IOPS')
# NAB_data_Traffic_5.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+genesis-anomalies.test.csv@13.out: ('NAB', 'KDD21', 'Genesis')
# NAB_data_Traffic_5.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'KDD21', 'YAHOO')
# NAB_data_Traffic_5.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+101-freeway-traffic.test.out: ('NAB', 'KDD21', 'Dodgers')
# NAB_data_Traffic_5.out+M-3.train.out+stb-3.test.out: ('NAB', 'NASA-MSL', 'SensorScope')
# NAB_data_Traffic_5.out+M-6.test.out+room-occupancy-0.test.csv@3.out: ('NAB', 'NASA-MSL', 'Occupancy')
# NAB_data_Traffic_5.out+M-3.train.out+S09R01E0.test.csv@1.out: ('NAB', 'NASA-MSL', 'Daphnet')
# NAB_data_Exchange_2.out+M-3.train.out+S2-ADL5.test.csv@81.out: ('NAB', 'NASA-MSL', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+M-6.test.out+870.test.csv@2.out: ('NAB', 'NASA-MSL', 'SVDB')
# NAB_data_Exchange_2.out+M-3.train.out+machine-2-8.test.csv@32.out: ('NAB', 'NASA-MSL', 'SMD')
# NAB_data_Exchange_2.out+M-6.test.out+3.test.out: ('NAB', 'NASA-MSL', 'MGAB')
# NAB_data_Traffic_5.out+M-3.train.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('NAB', 'NASA-MSL', 'IOPS')
# NAB_data_Traffic_5.out+M-3.train.out+genesis-anomalies.test.csv@13.out: ('NAB', 'NASA-MSL', 'Genesis')
# NAB_data_Exchange_2.out+M-6.test.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'NASA-MSL', 'YAHOO')
# NAB_data_Traffic_5.out+M-6.test.out+101-freeway-traffic.test.out: ('NAB', 'NASA-MSL', 'Dodgers')
# NAB_data_Traffic_5.out+stb-3.test.out+room-occupancy-0.test.csv@3.out: ('NAB', 'SensorScope', 'Occupancy')
# NAB_data_Exchange_2.out+stb-3.test.out+S03R01E1.test.csv@2.out: ('NAB', 'SensorScope', 'Daphnet')
# NAB_data_Exchange_2.out+stb-7.test.out+S2-ADL5.test.csv@81.out: ('NAB', 'SensorScope', 'OPPORTUNITY')
# NAB_data_Traffic_5.out+stb-7.test.out+870.test.csv@2.out: ('NAB', 'SensorScope', 'SVDB')
# NAB_data_Exchange_2.out+stb-3.test.out+machine-2-8.test.csv@32.out: ('NAB', 'SensorScope', 'SMD')
# NAB_data_Exchange_2.out+stb-3.test.out+3.test.out: ('NAB', 'SensorScope', 'MGAB')
# NAB_data_Exchange_2.out+stb-7.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('NAB', 'SensorScope', 'IOPS')
# NAB_data_Traffic_5.out+stb-3.test.out+genesis-anomalies.test.csv@6.out: ('NAB', 'SensorScope', 'Genesis')
# NAB_data_Traffic_5.out+stb-7.test.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'SensorScope', 'YAHOO')
# NAB_data_Exchange_2.out+stb-7.test.out+101-freeway-traffic.test.out: ('NAB', 'SensorScope', 'Dodgers')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out+S03R01E1.test.csv@2.out: ('NAB', 'Occupancy', 'Daphnet')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out+S4-ADL4.test.csv@108.out: ('NAB', 'Occupancy', 'OPPORTUNITY')
# NAB_data_Traffic_5.out+room-occupancy-0.test.csv@3.out+806.test.csv@1.out: ('NAB', 'Occupancy', 'SVDB')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out+machine-1-1.test.csv@19.out: ('NAB', 'Occupancy', 'SMD')
# NAB_data_Traffic_5.out+room-occupancy-0.test.csv@3.out+9.test.out: ('NAB', 'Occupancy', 'MGAB')
# NAB_data_Traffic_5.out+room-occupancy-0.test.csv@3.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('NAB', 'Occupancy', 'IOPS')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out+genesis-anomalies.test.csv@5.out: ('NAB', 'Occupancy', 'Genesis')
# NAB_data_Exchange_2.out+room-occupancy-0.test.csv@3.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'Occupancy', 'YAHOO')
# NAB_data_Traffic_5.out+room-occupancy-0.test.csv@3.out+101-freeway-traffic.test.out: ('NAB', 'Occupancy', 'Dodgers')
# NAB_data_Exchange_2.out+S03R01E1.test.csv@2.out+S2-ADL5.test.csv@81.out: ('NAB', 'Daphnet', 'OPPORTUNITY')
# NAB_data_Exchange_2.out+S09R01E0.test.csv@1.out+806.test.csv@1.out: ('NAB', 'Daphnet', 'SVDB')
# NAB_data_Exchange_2.out+S09R01E0.test.csv@1.out+machine-2-8.test.csv@32.out: ('NAB', 'Daphnet', 'SMD')
# NAB_data_Exchange_2.out+S09R01E0.test.csv@1.out+3.test.out: ('NAB', 'Daphnet', 'MGAB')
# NAB_data_Exchange_2.out+S09R01E0.test.csv@1.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('NAB', 'Daphnet', 'IOPS')
# NAB_data_Exchange_2.out+S03R01E1.test.csv@2.out+genesis-anomalies.test.csv@13.out: ('NAB', 'Daphnet', 'Genesis')
# NAB_data_Traffic_5.out+S03R01E0.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'Daphnet', 'YAHOO')
# NAB_data_Exchange_2.out+S03R01E1.test.csv@2.out+101-freeway-traffic.test.out: ('NAB', 'Daphnet', 'Dodgers')
# NAB_data_Exchange_2.out+S4-ADL4.test.csv@108.out+870.test.csv@2.out: ('NAB', 'OPPORTUNITY', 'SVDB')
# NAB_data_Exchange_2.out+S4-ADL4.test.csv@108.out+machine-3-5.test.csv@31.out: ('NAB', 'OPPORTUNITY', 'SMD')
# NAB_data_Exchange_2.out+S4-ADL4.test.csv@108.out+3.test.out: ('NAB', 'OPPORTUNITY', 'MGAB')
# NAB_data_Traffic_5.out+S2-ADL5.test.csv@81.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('NAB', 'OPPORTUNITY', 'IOPS')
# NAB_data_Exchange_2.out+S2-ADL5.test.csv@81.out+genesis-anomalies.test.csv@13.out: ('NAB', 'OPPORTUNITY', 'Genesis')
# NAB_data_Traffic_5.out+S4-ADL4.test.csv@108.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'OPPORTUNITY', 'YAHOO')
# NAB_data_Exchange_2.out+S2-ADL5.test.csv@81.out+101-freeway-traffic.test.out: ('NAB', 'OPPORTUNITY', 'Dodgers')
# NAB_data_Traffic_5.out+870.test.csv@2.out+machine-1-1.test.csv@19.out: ('NAB', 'SVDB', 'SMD')
# NAB_data_Traffic_5.out+870.test.csv@2.out+3.test.out: ('NAB', 'SVDB', 'MGAB')
# NAB_data_Traffic_5.out+806.test.csv@1.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NAB', 'SVDB', 'IOPS')
# NAB_data_Exchange_2.out+870.test.csv@2.out+genesis-anomalies.test.csv@13.out: ('NAB', 'SVDB', 'Genesis')
# NAB_data_Exchange_2.out+870.test.csv@2.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'SVDB', 'YAHOO')
# NAB_data_Traffic_5.out+870.test.csv@2.out+101-freeway-traffic.test.out: ('NAB', 'SVDB', 'Dodgers')
# NAB_data_Exchange_2.out+machine-3-5.test.csv@31.out+9.test.out: ('NAB', 'SMD', 'MGAB')
# NAB_data_Exchange_2.out+machine-1-1.test.csv@19.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NAB', 'SMD', 'IOPS')
# NAB_data_Exchange_2.out+machine-2-8.test.csv@32.out+genesis-anomalies.test.csv@5.out: ('NAB', 'SMD', 'Genesis')
# NAB_data_Traffic_5.out+machine-3-5.test.csv@31.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'SMD', 'YAHOO')
# NAB_data_Traffic_5.out+machine-3-5.test.csv@31.out+101-freeway-traffic.test.out: ('NAB', 'SMD', 'Dodgers')
# NAB_data_Traffic_5.out+3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('NAB', 'MGAB', 'IOPS')
# NAB_data_Exchange_2.out+3.test.out+genesis-anomalies.test.csv@13.out: ('NAB', 'MGAB', 'Genesis')
# NAB_data_Exchange_2.out+3.test.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'MGAB', 'YAHOO')
# NAB_data_Exchange_2.out+9.test.out+101-freeway-traffic.test.out: ('NAB', 'MGAB', 'Dodgers')
# NAB_data_Traffic_5.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+genesis-anomalies.test.csv@13.out: ('NAB', 'IOPS', 'Genesis')
# NAB_data_Exchange_2.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'IOPS', 'YAHOO')
# NAB_data_Exchange_2.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+101-freeway-traffic.test.out: ('NAB', 'IOPS', 'Dodgers')
# NAB_data_Exchange_2.out+genesis-anomalies.test.csv@6.out+YahooA3Benchmark-TS29_data.out: ('NAB', 'Genesis', 'YAHOO')
# NAB_data_Exchange_2.out+genesis-anomalies.test.csv@13.out+101-freeway-traffic.test.out: ('NAB', 'Genesis', 'Dodgers')
# NAB_data_Traffic_5.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('NAB', 'YAHOO', 'Dodgers')
# MBA_ECG14046_data_11.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+D-13.train.out: ('ECG', 'GHL', 'NASA-SMAP')
# MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ('ECG', 'GHL', 'KDD21')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+M-3.train.out: ('ECG', 'GHL', 'NASA-MSL')
# MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-3.test.out: ('ECG', 'GHL', 'SensorScope')
# MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+room-occupancy-0.test.csv@3.out: ('ECG', 'GHL', 'Occupancy')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S09R01E0.test.csv@1.out: ('ECG', 'GHL', 'Daphnet')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+S4-ADL4.test.csv@108.out: ('ECG', 'GHL', 'OPPORTUNITY')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+870.test.csv@2.out: ('ECG', 'GHL', 'SVDB')
# MBA_ECG14046_data_12.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+machine-2-8.test.csv@32.out: ('ECG', 'GHL', 'SMD')
# MBA_ECG14046_data_11.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+3.test.out: ('ECG', 'GHL', 'MGAB')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('ECG', 'GHL', 'IOPS')
# MBA_ECG14046_data_11.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+genesis-anomalies.test.csv@13.out: ('ECG', 'GHL', 'Genesis')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('ECG', 'GHL', 'YAHOO')
# MBA_ECG14046_data_37.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+101-freeway-traffic.test.out: ('ECG', 'GHL', 'Dodgers')
# MBA_ECG14046_data_37.out+D-8.test.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out: ('ECG', 'NASA-SMAP', 'KDD21')
# MBA_ECG14046_data_11.out+A-8.train.out+M-6.test.out: ('ECG', 'NASA-SMAP', 'NASA-MSL')
# MBA_ECG14046_data_11.out+D-8.test.out+stb-3.test.out: ('ECG', 'NASA-SMAP', 'SensorScope')
# MBA_ECG14046_data_11.out+D-8.test.out+room-occupancy-0.test.csv@3.out: ('ECG', 'NASA-SMAP', 'Occupancy')
# MBA_ECG14046_data_11.out+A-8.train.out+S03R01E1.test.csv@2.out: ('ECG', 'NASA-SMAP', 'Daphnet')
# MBA_ECG14046_data_11.out+A-8.train.out+S4-ADL4.test.csv@108.out: ('ECG', 'NASA-SMAP', 'OPPORTUNITY')
# MBA_ECG14046_data_12.out+A-8.train.out+870.test.csv@2.out: ('ECG', 'NASA-SMAP', 'SVDB')
# MBA_ECG14046_data_37.out+A-8.train.out+machine-1-1.test.csv@19.out: ('ECG', 'NASA-SMAP', 'SMD')
# MBA_ECG14046_data_37.out+D-13.train.out+3.test.out: ('ECG', 'NASA-SMAP', 'MGAB')
# MBA_ECG14046_data_37.out+D-8.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('ECG', 'NASA-SMAP', 'IOPS')
# MBA_ECG14046_data_12.out+A-8.train.out+genesis-anomalies.test.csv@6.out: ('ECG', 'NASA-SMAP', 'Genesis')
# MBA_ECG14046_data_37.out+D-8.test.out+YahooA3Benchmark-TS29_data.out: ('ECG', 'NASA-SMAP', 'YAHOO')
# MBA_ECG14046_data_12.out+D-13.train.out+101-freeway-traffic.test.out: ('ECG', 'NASA-SMAP', 'Dodgers')
# MBA_ECG14046_data_37.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+M-6.test.out: ('ECG', 'KDD21', 'NASA-MSL')
# MBA_ECG14046_data_12.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+stb-3.test.out: ('ECG', 'KDD21', 'SensorScope')
# MBA_ECG14046_data_11.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+room-occupancy-0.test.csv@3.out: ('ECG', 'KDD21', 'Occupancy')
# MBA_ECG14046_data_11.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+S03R01E0.test.csv@8.out: ('ECG', 'KDD21', 'Daphnet')
# MBA_ECG14046_data_37.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+S2-ADL5.test.csv@81.out: ('ECG', 'KDD21', 'OPPORTUNITY')
# MBA_ECG14046_data_11.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+870.test.csv@2.out: ('ECG', 'KDD21', 'SVDB')
# MBA_ECG14046_data_11.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+machine-1-1.test.csv@19.out: ('ECG', 'KDD21', 'SMD')
# MBA_ECG14046_data_37.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+3.test.out: ('ECG', 'KDD21', 'MGAB')
# MBA_ECG14046_data_37.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('ECG', 'KDD21', 'IOPS')
# MBA_ECG14046_data_12.out+080_UCR_Anomaly_DISTORTEDresperation2_30000_168250_168251.out+genesis-anomalies.test.csv@13.out: ('ECG', 'KDD21', 'Genesis')
# MBA_ECG14046_data_12.out+073_UCR_Anomaly_DISTORTEDpark3m_60000_72150_72495.out+YahooA3Benchmark-TS29_data.out: ('ECG', 'KDD21', 'YAHOO')
# MBA_ECG14046_data_37.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+101-freeway-traffic.test.out: ('ECG', 'KDD21', 'Dodgers')
# MBA_ECG14046_data_11.out+M-6.test.out+stb-3.test.out: ('ECG', 'NASA-MSL', 'SensorScope')
# MBA_ECG14046_data_12.out+M-3.train.out+room-occupancy-0.test.csv@3.out: ('ECG', 'NASA-MSL', 'Occupancy')
# MBA_ECG14046_data_11.out+M-6.test.out+S03R01E1.test.csv@2.out: ('ECG', 'NASA-MSL', 'Daphnet')
# MBA_ECG14046_data_12.out+M-3.train.out+S2-ADL5.test.csv@81.out: ('ECG', 'NASA-MSL', 'OPPORTUNITY')
# MBA_ECG14046_data_37.out+M-3.train.out+806.test.csv@1.out: ('ECG', 'NASA-MSL', 'SVDB')
# MBA_ECG14046_data_11.out+M-6.test.out+machine-2-8.test.csv@32.out: ('ECG', 'NASA-MSL', 'SMD')
# MBA_ECG14046_data_37.out+M-3.train.out+3.test.out: ('ECG', 'NASA-MSL', 'MGAB')
# MBA_ECG14046_data_37.out+M-6.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('ECG', 'NASA-MSL', 'IOPS')
# MBA_ECG14046_data_11.out+M-6.test.out+genesis-anomalies.test.csv@13.out: ('ECG', 'NASA-MSL', 'Genesis')
# MBA_ECG14046_data_11.out+M-6.test.out+YahooA3Benchmark-TS29_data.out: ('ECG', 'NASA-MSL', 'YAHOO')
# MBA_ECG14046_data_11.out+M-3.train.out+101-freeway-traffic.test.out: ('ECG', 'NASA-MSL', 'Dodgers')
# MBA_ECG14046_data_37.out+stb-3.test.out+room-occupancy-0.test.csv@3.out: ('ECG', 'SensorScope', 'Occupancy')
# MBA_ECG14046_data_37.out+stb-7.test.out+S03R01E0.test.csv@8.out: ('ECG', 'SensorScope', 'Daphnet')
# MBA_ECG14046_data_12.out+stb-7.test.out+S4-ADL4.test.csv@108.out: ('ECG', 'SensorScope', 'OPPORTUNITY')
# MBA_ECG14046_data_12.out+stb-3.test.out+806.test.csv@1.out: ('ECG', 'SensorScope', 'SVDB')
# MBA_ECG14046_data_37.out+stb-3.test.out+machine-2-8.test.csv@32.out: ('ECG', 'SensorScope', 'SMD')
# MBA_ECG14046_data_37.out+stb-7.test.out+3.test.out: ('ECG', 'SensorScope', 'MGAB')
# MBA_ECG14046_data_12.out+stb-7.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('ECG', 'SensorScope', 'IOPS')
# ...
# stb-7.test.out+806.test.csv@1.out+genesis-anomalies.test.csv@6.out: ('SensorScope', 'SVDB', 'Genesis')
# stb-7.test.out+870.test.csv@2.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'SVDB', 'YAHOO')
# stb-7.test.out+870.test.csv@2.out+101-freeway-traffic.test.out: ('SensorScope', 'SVDB', 'Dodgers')
# stb-3.test.out+machine-1-1.test.csv@19.out+9.test.out: ('SensorScope', 'SMD', 'MGAB')
# stb-7.test.out+machine-1-1.test.csv@19.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('SensorScope', 'SMD', 'IOPS')
# stb-3.test.out+machine-2-8.test.csv@32.out+genesis-anomalies.test.csv@5.out: ('SensorScope', 'SMD', 'Genesis')
# stb-7.test.out+machine-1-1.test.csv@19.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'SMD', 'YAHOO')
# stb-7.test.out+machine-2-8.test.csv@32.out+101-freeway-traffic.test.out: ('SensorScope', 'SMD', 'Dodgers')
# stb-7.test.out+3.test.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('SensorScope', 'MGAB', 'IOPS')
# stb-3.test.out+9.test.out+genesis-anomalies.test.csv@5.out: ('SensorScope', 'MGAB', 'Genesis')
# stb-7.test.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'MGAB', 'YAHOO')
# stb-7.test.out+9.test.out+101-freeway-traffic.test.out: ('SensorScope', 'MGAB', 'Dodgers')
# stb-3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+genesis-anomalies.test.csv@6.out: ('SensorScope', 'IOPS', 'Genesis')
# stb-3.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'IOPS', 'YAHOO')
# stb-3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ('SensorScope', 'IOPS', 'Dodgers')
# stb-3.test.out+genesis-anomalies.test.csv@6.out+YahooA3Benchmark-TS29_data.out: ('SensorScope', 'Genesis', 'YAHOO')
# stb-3.test.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('SensorScope', 'Genesis', 'Dodgers')
# stb-7.test.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('SensorScope', 'YAHOO', 'Dodgers')
# room-occupancy-0.test.csv@3.out+S03R01E1.test.csv@2.out+S2-ADL5.test.csv@81.out: ('Occupancy', 'Daphnet', 'OPPORTUNITY')
# room-occupancy-0.test.csv@3.out+S03R01E1.test.csv@2.out+806.test.csv@1.out: ('Occupancy', 'Daphnet', 'SVDB')
# room-occupancy-0.test.csv@3.out+S09R01E0.test.csv@1.out+machine-2-8.test.csv@32.out: ('Occupancy', 'Daphnet', 'SMD')
# room-occupancy-0.test.csv@3.out+S03R01E0.test.csv@8.out+9.test.out: ('Occupancy', 'Daphnet', 'MGAB')
# room-occupancy-0.test.csv@3.out+S03R01E0.test.csv@8.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('Occupancy', 'Daphnet', 'IOPS')
# room-occupancy-0.test.csv@3.out+S03R01E1.test.csv@2.out+genesis-anomalies.test.csv@13.out: ('Occupancy', 'Daphnet', 'Genesis')
# room-occupancy-0.test.csv@3.out+S03R01E0.test.csv@8.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'Daphnet', 'YAHOO')
# room-occupancy-0.test.csv@3.out+S09R01E0.test.csv@1.out+101-freeway-traffic.test.out: ('Occupancy', 'Daphnet', 'Dodgers')
# room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out+806.test.csv@1.out: ('Occupancy', 'OPPORTUNITY', 'SVDB')
# room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out+machine-1-1.test.csv@19.out: ('Occupancy', 'OPPORTUNITY', 'SMD')
# room-occupancy-0.test.csv@3.out+S4-ADL4.test.csv@108.out+3.test.out: ('Occupancy', 'OPPORTUNITY', 'MGAB')
# room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('Occupancy', 'OPPORTUNITY', 'IOPS')
# room-occupancy-0.test.csv@3.out+S4-ADL4.test.csv@108.out+genesis-anomalies.test.csv@6.out: ('Occupancy', 'OPPORTUNITY', 'Genesis')
# room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'OPPORTUNITY', 'YAHOO')
# room-occupancy-0.test.csv@3.out+S2-ADL5.test.csv@81.out+101-freeway-traffic.test.out: ('Occupancy', 'OPPORTUNITY', 'Dodgers')
# room-occupancy-0.test.csv@3.out+806.test.csv@1.out+machine-2-8.test.csv@32.out: ('Occupancy', 'SVDB', 'SMD')
# room-occupancy-0.test.csv@3.out+806.test.csv@1.out+3.test.out: ('Occupancy', 'SVDB', 'MGAB')
# room-occupancy-0.test.csv@3.out+870.test.csv@2.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Occupancy', 'SVDB', 'IOPS')
# room-occupancy-0.test.csv@3.out+806.test.csv@1.out+genesis-anomalies.test.csv@13.out: ('Occupancy', 'SVDB', 'Genesis')
# room-occupancy-0.test.csv@3.out+870.test.csv@2.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'SVDB', 'YAHOO')
# room-occupancy-0.test.csv@3.out+870.test.csv@2.out+101-freeway-traffic.test.out: ('Occupancy', 'SVDB', 'Dodgers')
# room-occupancy-0.test.csv@3.out+machine-3-5.test.csv@31.out+9.test.out: ('Occupancy', 'SMD', 'MGAB')
# room-occupancy-0.test.csv@3.out+machine-3-5.test.csv@31.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Occupancy', 'SMD', 'IOPS')
# room-occupancy-0.test.csv@3.out+machine-1-1.test.csv@19.out+genesis-anomalies.test.csv@6.out: ('Occupancy', 'SMD', 'Genesis')
# room-occupancy-0.test.csv@3.out+machine-3-5.test.csv@31.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'SMD', 'YAHOO')
# room-occupancy-0.test.csv@3.out+machine-2-8.test.csv@32.out+101-freeway-traffic.test.out: ('Occupancy', 'SMD', 'Dodgers')
# room-occupancy-0.test.csv@3.out+3.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('Occupancy', 'MGAB', 'IOPS')
# room-occupancy-0.test.csv@3.out+9.test.out+genesis-anomalies.test.csv@5.out: ('Occupancy', 'MGAB', 'Genesis')
# room-occupancy-0.test.csv@3.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'MGAB', 'YAHOO')
# room-occupancy-0.test.csv@3.out+3.test.out+101-freeway-traffic.test.out: ('Occupancy', 'MGAB', 'Dodgers')
# room-occupancy-0.test.csv@3.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+genesis-anomalies.test.csv@6.out: ('Occupancy', 'IOPS', 'Genesis')
# room-occupancy-0.test.csv@3.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'IOPS', 'YAHOO')
# room-occupancy-0.test.csv@3.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+101-freeway-traffic.test.out: ('Occupancy', 'IOPS', 'Dodgers')
# room-occupancy-0.test.csv@3.out+genesis-anomalies.test.csv@13.out+YahooA3Benchmark-TS29_data.out: ('Occupancy', 'Genesis', 'YAHOO')
# room-occupancy-0.test.csv@3.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('Occupancy', 'Genesis', 'Dodgers')
# room-occupancy-0.test.csv@3.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('Occupancy', 'YAHOO', 'Dodgers')
# S03R01E1.test.csv@2.out+S4-ADL4.test.csv@108.out+870.test.csv@2.out: ('Daphnet', 'OPPORTUNITY', 'SVDB')
# S03R01E0.test.csv@8.out+S4-ADL4.test.csv@108.out+machine-2-8.test.csv@32.out: ('Daphnet', 'OPPORTUNITY', 'SMD')
# S03R01E0.test.csv@8.out+S2-ADL5.test.csv@81.out+3.test.out: ('Daphnet', 'OPPORTUNITY', 'MGAB')
# S09R01E0.test.csv@1.out+S4-ADL4.test.csv@108.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Daphnet', 'OPPORTUNITY', 'IOPS')
# S03R01E1.test.csv@2.out+S4-ADL4.test.csv@108.out+genesis-anomalies.test.csv@5.out: ('Daphnet', 'OPPORTUNITY', 'Genesis')
# S03R01E0.test.csv@8.out+S4-ADL4.test.csv@108.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'OPPORTUNITY', 'YAHOO')
# S09R01E0.test.csv@1.out+S2-ADL5.test.csv@81.out+101-freeway-traffic.test.out: ('Daphnet', 'OPPORTUNITY', 'Dodgers')
# S03R01E0.test.csv@8.out+870.test.csv@2.out+machine-2-8.test.csv@32.out: ('Daphnet', 'SVDB', 'SMD')
# S03R01E0.test.csv@8.out+806.test.csv@1.out+9.test.out: ('Daphnet', 'SVDB', 'MGAB')
# S09R01E0.test.csv@1.out+870.test.csv@2.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('Daphnet', 'SVDB', 'IOPS')
# S03R01E0.test.csv@8.out+870.test.csv@2.out+genesis-anomalies.test.csv@6.out: ('Daphnet', 'SVDB', 'Genesis')
# S09R01E0.test.csv@1.out+870.test.csv@2.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'SVDB', 'YAHOO')
# S03R01E0.test.csv@8.out+806.test.csv@1.out+101-freeway-traffic.test.out: ('Daphnet', 'SVDB', 'Dodgers')
# S03R01E0.test.csv@8.out+machine-1-1.test.csv@19.out+3.test.out: ('Daphnet', 'SMD', 'MGAB')
# S09R01E0.test.csv@1.out+machine-3-5.test.csv@31.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Daphnet', 'SMD', 'IOPS')
# S03R01E0.test.csv@8.out+machine-1-1.test.csv@19.out+genesis-anomalies.test.csv@6.out: ('Daphnet', 'SMD', 'Genesis')
# S09R01E0.test.csv@1.out+machine-3-5.test.csv@31.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'SMD', 'YAHOO')
# S03R01E1.test.csv@2.out+machine-3-5.test.csv@31.out+101-freeway-traffic.test.out: ('Daphnet', 'SMD', 'Dodgers')
# S03R01E0.test.csv@8.out+9.test.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('Daphnet', 'MGAB', 'IOPS')
# S03R01E1.test.csv@2.out+9.test.out+genesis-anomalies.test.csv@13.out: ('Daphnet', 'MGAB', 'Genesis')
# S03R01E1.test.csv@2.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'MGAB', 'YAHOO')
# S03R01E1.test.csv@2.out+9.test.out+101-freeway-traffic.test.out: ('Daphnet', 'MGAB', 'Dodgers')
# S03R01E1.test.csv@2.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+genesis-anomalies.test.csv@13.out: ('Daphnet', 'IOPS', 'Genesis')
# S03R01E0.test.csv@8.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'IOPS', 'YAHOO')
# S03R01E0.test.csv@8.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ('Daphnet', 'IOPS', 'Dodgers')
# S03R01E0.test.csv@8.out+genesis-anomalies.test.csv@13.out+YahooA3Benchmark-TS29_data.out: ('Daphnet', 'Genesis', 'YAHOO')
# S03R01E0.test.csv@8.out+genesis-anomalies.test.csv@13.out+101-freeway-traffic.test.out: ('Daphnet', 'Genesis', 'Dodgers')
# S03R01E1.test.csv@2.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('Daphnet', 'YAHOO', 'Dodgers')
# S2-ADL5.test.csv@81.out+870.test.csv@2.out+machine-3-5.test.csv@31.out: ('OPPORTUNITY', 'SVDB', 'SMD')
# S4-ADL4.test.csv@108.out+806.test.csv@1.out+3.test.out: ('OPPORTUNITY', 'SVDB', 'MGAB')
# S2-ADL5.test.csv@81.out+870.test.csv@2.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('OPPORTUNITY', 'SVDB', 'IOPS')
# S2-ADL5.test.csv@81.out+870.test.csv@2.out+genesis-anomalies.test.csv@5.out: ('OPPORTUNITY', 'SVDB', 'Genesis')
# S4-ADL4.test.csv@108.out+806.test.csv@1.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'SVDB', 'YAHOO')
# S4-ADL4.test.csv@108.out+870.test.csv@2.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'SVDB', 'Dodgers')
# S2-ADL5.test.csv@81.out+machine-1-1.test.csv@19.out+3.test.out: ('OPPORTUNITY', 'SMD', 'MGAB')
# S2-ADL5.test.csv@81.out+machine-1-1.test.csv@19.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('OPPORTUNITY', 'SMD', 'IOPS')
# S2-ADL5.test.csv@81.out+machine-2-8.test.csv@32.out+genesis-anomalies.test.csv@6.out: ('OPPORTUNITY', 'SMD', 'Genesis')
# S4-ADL4.test.csv@108.out+machine-3-5.test.csv@31.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'SMD', 'YAHOO')
# S2-ADL5.test.csv@81.out+machine-3-5.test.csv@31.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'SMD', 'Dodgers')
# S2-ADL5.test.csv@81.out+3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out: ('OPPORTUNITY', 'MGAB', 'IOPS')
# S4-ADL4.test.csv@108.out+3.test.out+genesis-anomalies.test.csv@5.out: ('OPPORTUNITY', 'MGAB', 'Genesis')
# S2-ADL5.test.csv@81.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'MGAB', 'YAHOO')
# S2-ADL5.test.csv@81.out+9.test.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'MGAB', 'Dodgers')
# S4-ADL4.test.csv@108.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+genesis-anomalies.test.csv@13.out: ('OPPORTUNITY', 'IOPS', 'Genesis')
# S4-ADL4.test.csv@108.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'IOPS', 'YAHOO')
# S2-ADL5.test.csv@81.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'IOPS', 'Dodgers')
# S4-ADL4.test.csv@108.out+genesis-anomalies.test.csv@13.out+YahooA3Benchmark-TS29_data.out: ('OPPORTUNITY', 'Genesis', 'YAHOO')
# S4-ADL4.test.csv@108.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'Genesis', 'Dodgers')
# S2-ADL5.test.csv@81.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('OPPORTUNITY', 'YAHOO', 'Dodgers')
# 806.test.csv@1.out+machine-2-8.test.csv@32.out+3.test.out: ('SVDB', 'SMD', 'MGAB')
# 806.test.csv@1.out+machine-1-1.test.csv@19.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('SVDB', 'SMD', 'IOPS')
# 870.test.csv@2.out+machine-1-1.test.csv@19.out+genesis-anomalies.test.csv@5.out: ('SVDB', 'SMD', 'Genesis')
# 870.test.csv@2.out+machine-2-8.test.csv@32.out+YahooA3Benchmark-TS29_data.out: ('SVDB', 'SMD', 'YAHOO')
# 870.test.csv@2.out+machine-1-1.test.csv@19.out+101-freeway-traffic.test.out: ('SVDB', 'SMD', 'Dodgers')
# 870.test.csv@2.out+9.test.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out: ('SVDB', 'MGAB', 'IOPS')
# 806.test.csv@1.out+3.test.out+genesis-anomalies.test.csv@5.out: ('SVDB', 'MGAB', 'Genesis')
# 806.test.csv@1.out+3.test.out+YahooA3Benchmark-TS29_data.out: ('SVDB', 'MGAB', 'YAHOO')
# 870.test.csv@2.out+9.test.out+101-freeway-traffic.test.out: ('SVDB', 'MGAB', 'Dodgers')
# 870.test.csv@2.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+genesis-anomalies.test.csv@5.out: ('SVDB', 'IOPS', 'Genesis')
# 806.test.csv@1.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+YahooA3Benchmark-TS29_data.out: ('SVDB', 'IOPS', 'YAHOO')
# 806.test.csv@1.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+101-freeway-traffic.test.out: ('SVDB', 'IOPS', 'Dodgers')
# 806.test.csv@1.out+genesis-anomalies.test.csv@5.out+YahooA3Benchmark-TS29_data.out: ('SVDB', 'Genesis', 'YAHOO')
# 806.test.csv@1.out+genesis-anomalies.test.csv@13.out+101-freeway-traffic.test.out: ('SVDB', 'Genesis', 'Dodgers')
# 870.test.csv@2.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('SVDB', 'YAHOO', 'Dodgers')
# machine-3-5.test.csv@31.out+3.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out: ('SMD', 'MGAB', 'IOPS')
# machine-1-1.test.csv@19.out+9.test.out+genesis-anomalies.test.csv@13.out: ('SMD', 'MGAB', 'Genesis')
# machine-3-5.test.csv@31.out+9.test.out+YahooA3Benchmark-TS29_data.out: ('SMD', 'MGAB', 'YAHOO')
# machine-2-8.test.csv@32.out+3.test.out+101-freeway-traffic.test.out: ('SMD', 'MGAB', 'Dodgers')
# machine-3-5.test.csv@31.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+genesis-anomalies.test.csv@13.out: ('SMD', 'IOPS', 'Genesis')
# machine-2-8.test.csv@32.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+YahooA3Benchmark-TS29_data.out: ('SMD', 'IOPS', 'YAHOO')
# machine-3-5.test.csv@31.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ('SMD', 'IOPS', 'Dodgers')
# machine-1-1.test.csv@19.out+genesis-anomalies.test.csv@5.out+YahooA3Benchmark-TS29_data.out: ('SMD', 'Genesis', 'YAHOO')
# machine-1-1.test.csv@19.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('SMD', 'Genesis', 'Dodgers')
# machine-3-5.test.csv@31.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('SMD', 'YAHOO', 'Dodgers')
# 9.test.out+KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+genesis-anomalies.test.csv@13.out: ('MGAB', 'IOPS', 'Genesis')
# 3.test.out+KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+YahooA3Benchmark-TS29_data.out: ('MGAB', 'IOPS', 'YAHOO')
# 3.test.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ('MGAB', 'IOPS', 'Dodgers')
# 3.test.out+genesis-anomalies.test.csv@6.out+YahooA3Benchmark-TS29_data.out: ('MGAB', 'Genesis', 'YAHOO')
# 9.test.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('MGAB', 'Genesis', 'Dodgers')
# 3.test.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('MGAB', 'YAHOO', 'Dodgers')
# KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+genesis-anomalies.test.csv@6.out+YahooA3Benchmark-TS29_data.out: ('IOPS', 'Genesis', 'YAHOO')
# KPI-a8c06b47-cc41-3738-9110-12df0ee4c721.test.out+genesis-anomalies.test.csv@6.out+101-freeway-traffic.test.out: ('IOPS', 'Genesis', 'Dodgers')
# KPI-1c6d7a26-1f1a-3321-bb4d-7a9d969ec8f0.test.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('IOPS', 'YAHOO', 'Dodgers')
# genesis-anomalies.test.csv@13.out+YahooA3Benchmark-TS29_data.out+101-freeway-traffic.test.out: ('Genesis', 'YAHOO', 'Dodgers')

# %%
def create_combined_dict(normality_1, normality_2, normality_3):
    combined_dict = {}
    counts = {"Normality_1": 0, "Normality_2": 0, "Normality_3": 0}

    # Adding from Normality_1
    for subfolder, files in normality_1.items():
        for file in files:
            if file not in combined_dict:
                combined_dict[file] = ["Normality_1", subfolder]
                counts["Normality_1"] += 1

    # Adding from Normality_2
    for key, subfolders in normality_2.items():
        if key not in combined_dict:
            combined_dict[key] = ["Normality_2", subfolders[0], subfolders[1]]
            counts["Normality_2"] += 1

    # Adding from Normality_3
    for key, subfolders in normality_3.items():
        if key not in combined_dict:
            combined_dict[key] = ["Normality_3", subfolders[0], subfolders[1], subfolders[2]]
            counts["Normality_3"] += 1

    return combined_dict, counts

# %%
combined_dict, counts = create_combined_dict(normality_1, normality_2, normality_3)

# %%
# Print the counts of filenames from each normality
print("\nCounts of filenames from each normality:")
for normality, count in counts.items():
    print(f"{normality}: {count}")
# Out:
# Counts of filenames from each normality:
# Normality_1: 40
# Normality_2: 153
# Normality_3: 816

# %%
# Predefined number of items to take from each normality
normality_1_count = 10
normality_2_count = 10
normality_3_count = 10

# %%
def create_predefined_dict(combined_dict, normality_1_count, normality_2_count, normality_3_count):
    predefined_dict = {"Normality_1": {}, "Normality_2": {}, "Normality_3": {}}
    
    # Extracting specific numbers of items from each normality type
    normality_1_items = [item for item in combined_dict.items() if item[1][0] == "Normality_1"]
    normality_2_items = [item for item in combined_dict.items() if item[1][0] == "Normality_2"]
    normality_3_items = [item for item in combined_dict.items() if item[1][0] == "Normality_3"]
    
    # Select predefined numbers of items
    selected_normality_1_items = random.sample(normality_1_items, min(normality_1_count, len(normality_1_items)))
    selected_normality_2_items = random.sample(normality_2_items, min(normality_2_count, len(normality_2_items)))
    selected_normality_3_items = random.sample(normality_3_items, min(normality_3_count, len(normality_3_items)))
    
    # Combine selected items into the predefined_dict
    predefined_dict["Normality_1"] = dict(selected_normality_1_items)
    predefined_dict["Normality_2"] = dict(selected_normality_2_items)
    predefined_dict["Normality_3"] = dict(selected_normality_3_items)
    
    # Combine all selected items into a single dictionary
    all_selected_items = selected_normality_1_items + selected_normality_2_items + selected_normality_3_items
    
    # Shuffle the combined selected items
    random.shuffle(all_selected_items)
    
    # Convert to a dictionary
    shuffled_dict = dict(all_selected_items)
    
    return shuffled_dict

# %%
predefined_shuffled_dict = create_predefined_dict(combined_dict, normality_1_count, normality_2_count, normality_3_count)

# %%
# Print the shuffled dictionary
print("Predefined Shuffled Dictionary:")
for key, value in predefined_shuffled_dict.items():
    print(f"{key}: {value}")
# Out:
# Predefined Shuffled Dictionary:
# D-8.test.out+S4-ADL4.test.csv@108.out: ['Normality_2', 'NASA-SMAP', 'OPPORTUNITY']
# 039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+room-occupancy-0.test.csv@3.out+806.test.csv@1.out: ['Normality_3', 'KDD21', 'Occupancy', 'SVDB']
# YahooA3Benchmark-TS29_data.out: ['Normality_1', 'YAHOO']
# MBA_ECG14046_data_11.out+M-6.test.out+YahooA3Benchmark-TS29_data.out: ['Normality_3', 'ECG', 'NASA-MSL', 'YAHOO']
# A-8.train.out: ['Normality_1', 'NASA-SMAP']
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+101-freeway-traffic.test.out: ['Normality_3', 'GHL', 'KDD21', 'Dodgers']
# NAB_data_Traffic_5.out+9.test.out: ['Normality_2', 'NAB', 'MGAB']
# MBA_ECG14046_data_37.out+KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ['Normality_3', 'ECG', 'IOPS', 'Dodgers']
# 221.test.csv@1.out+M-3.train.out+3.test.out: ['Normality_3', 'MITDB', 'NASA-MSL', 'MGAB']
# M-6.test.out+genesis-anomalies.test.csv@13.out: ['Normality_2', 'NASA-MSL', 'Genesis']
# MBA_ECG14046_data_12.out: ['Normality_1', 'ECG']
# NAB_data_Traffic_5.out+MBA_ECG14046_data_11.out+genesis-anomalies.test.csv@5.out: ['Normality_3', 'NAB', 'ECG', 'Genesis']
# KPI-ffb82d38-5f00-37db-abc0-5d2e4e4cb6aa.test.out+101-freeway-traffic.test.out: ['Normality_2', 'IOPS', 'Dodgers']
# S03R01E1.test.csv@2.out: ['Normality_1', 'Daphnet']
# NAB_data_Traffic_5.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out: ['Normality_2', 'NAB', 'KDD21']
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+9.test.out: ['Normality_2', 'GHL', 'MGAB']
# MBA_ECG14046_data_11.out+S03R01E0.test.csv@8.out: ['Normality_2', 'ECG', 'Daphnet']
# genesis-anomalies.test.csv@13.out: ['Normality_1', 'Genesis']
# genesis-anomalies.test.csv@6.out: ['Normality_1', 'Genesis']
# 221.test.csv@1.out+15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out: ['Normality_2', 'MITDB', 'GHL']
# stb-3.test.out: ['Normality_1', 'SensorScope']
# machine-3-5.test.csv@31.out: ['Normality_1', 'SMD']
# 221.test.csv@1.out+NAB_data_Traffic_5.out+stb-7.test.out: ['Normality_3', 'MITDB', 'NAB', 'SensorScope']
# A-8.train.out+M-3.train.out: ['Normality_2', 'NASA-SMAP', 'NASA-MSL']
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-3.test.out+genesis-anomalies.test.csv@13.out: ['Normality_3', 'GHL', 'SensorScope', 'Genesis']
# D-13.train.out: ['Normality_1', 'NASA-SMAP']
# MBA_ECG14046_data_12.out+039_UCR_Anomaly_DISTORTEDLab2Cmac011215EPG3_5000_16390_16420.out+stb-3.test.out: ['Normality_3', 'ECG', 'KDD21', 'SensorScope']
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+D-8.test.out: ['Normality_2', 'GHL', 'NASA-SMAP']
# machine-1-1.test.csv@19.out: ['Normality_1', 'SMD']
# 15_Lev_fault_Temp_corr_seed_49_vars_23.test.csv@8.out+stb-7.test.out+870.test.csv@2.out: ['Normality_3', 'GHL', 'SensorScope', 'SVDB']

# %%
def create_files_and_new_dict(predefined_shuffled_dict, base_folder):
    new_dict = {}
    id_counter = 1

    for key, value in predefined_shuffled_dict.items():
        new_filename = f"ts{id_counter}"
        new_filepath = os.path.join('Time-Series-Data-Files/', new_filename)
        
        if value[0] == "Normality_1":
            subfolder = value[1]
            original_filepath = os.path.join(base_folder, subfolder, key)
            with open(original_filepath, 'r') as original_file:
                content = original_file.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_2":
            subfolder1, subfolder2 = value[1], value[2]
            file1, file2 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2:
                content = f1.read() + f2.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        elif value[0] == "Normality_3":
            subfolder1, subfolder2, subfolder3 = value[1], value[2], value[3]
            file1, file2, file3 = key.split('+')
            filepath1 = os.path.join(base_folder, subfolder1, file1)
            filepath2 = os.path.join(base_folder, subfolder2, file2)
            filepath3 = os.path.join(base_folder, subfolder3, file3)
            with open(filepath1, 'r') as f1, open(filepath2, 'r') as f2, open(filepath3, 'r') as f3:
                content = f1.read() + f2.read() + f3.read()
            with open(new_filepath, 'w') as new_file:
                new_file.write(content)
        
        new_dict[new_filename] = value
        id_counter += 1
    
    return new_dict

# %%
# Create files and the new dictionary
new_files_dict = create_files_and_new_dict(predefined_shuffled_dict, '../TSB-UAD-Public/TSB-UAD-Public')

# %%
# Print the new dictionary
print("New Dictionary with Generated Files:")
for key, value in new_files_dict.items():
    print(f"{key}: {value}")
# Out:
# New Dictionary with Generated Files:
# ts1: ['Normality_2', 'NASA-SMAP', 'OPPORTUNITY']
# ts2: ['Normality_3', 'KDD21', 'Occupancy', 'SVDB']
# ts3: ['Normality_1', 'YAHOO']
# ts4: ['Normality_3', 'ECG', 'NASA-MSL', 'YAHOO']
# ts5: ['Normality_1', 'NASA-SMAP']
# ts6: ['Normality_3', 'GHL', 'KDD21', 'Dodgers']
# ts7: ['Normality_2', 'NAB', 'MGAB']
# ts8: ['Normality_3', 'ECG', 'IOPS', 'Dodgers']
# ts9: ['Normality_3', 'MITDB', 'NASA-MSL', 'MGAB']
# ts10: ['Normality_2', 'NASA-MSL', 'Genesis']
# ts11: ['Normality_1', 'ECG']
# ts12: ['Normality_3', 'NAB', 'ECG', 'Genesis']
# ts13: ['Normality_2', 'IOPS', 'Dodgers']
# ts14: ['Normality_1', 'Daphnet']
# ts15: ['Normality_2', 'NAB', 'KDD21']
# ts16: ['Normality_2', 'GHL', 'MGAB']
# ts17: ['Normality_2', 'ECG', 'Daphnet']
# ts18: ['Normality_1', 'Genesis']
# ts19: ['Normality_1', 'Genesis']
# ts20: ['Normality_2', 'MITDB', 'GHL']
# ts21: ['Normality_1', 'SensorScope']
# ts22: ['Normality_1', 'SMD']
# ts23: ['Normality_3', 'MITDB', 'NAB', 'SensorScope']
# ts24: ['Normality_2', 'NASA-SMAP', 'NASA-MSL']
# ts25: ['Normality_3', 'GHL', 'SensorScope', 'Genesis']
# ts26: ['Normality_1', 'NASA-SMAP']
# ts27: ['Normality_3', 'ECG', 'KDD21', 'SensorScope']
# ts28: ['Normality_2', 'GHL', 'NASA-SMAP']
# ts29: ['Normality_1', 'SMD']
# ts30: ['Normality_3', 'GHL', 'SensorScope', 'SVDB']

# %% [markdown]
# # Non-Streaming Methods
# We pick two non-streaming methods of our choice as a baseline (e.g., Isolation Forest and a DNN
# method). We run the methods on the files of the dictionary we created in an eariler step. In the no streaming setting we use the entire generated files as input. These methods will serve as our offline baselines.
